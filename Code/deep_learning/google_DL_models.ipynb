# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
#For Pre-Processing
from tqdm import tqdm
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import RegexpTokenizer 
from nltk.tokenize import word_tokenize
import os, re, csv, math, codecs


# For Training
import keras
from keras import optimizers
from keras import backend as K
from keras import regularizers

from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Model,Sequential

# For array, dataset, and visualizing
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
np.random.seed(0)

MAX_NB_WORDS = 100000
tokenizer = RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))
stop_words.update(['।','.', ',', '"', "'", ':', ';', '(', ')', '[', ']', '{', '}'])




from sklearn.model_selection import train_test_split , LeaveOneOut
import pandas as pd
import numpy as np
np.random.seed(5)
import os
import keras.regularizers as regular
from keras.layers import Input, Dense,Conv1D,LSTM,GRU, Dropout, Flatten, Concatenate, MaxPool1D, Embedding, TimeDistributed, Bidirectional,Add, BatchNormalization
from keras.models import Model,Sequential
from keras import regularizers
import keras
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from tensorflow.keras.layers import Conv2D
from sklearn.metrics import mean_absolute_error
from imblearn.metrics import macro_averaged_mean_absolute_error
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !pip install indic-nlp-library
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.91-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.4 MB/s eta 0:00:00
# Collecting sphinx-argparse
#   Downloading sphinx_argparse-0.4.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from indic-nlp-library) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from indic-nlp-library) (1.5.3)
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-1.2.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 31.9 MB/s eta 0:00:00
# Collecting morfessor
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->indic-nlp-library) (2022.7.1)
# Requirement already satisfied: sphinx>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from sphinx-argparse->indic-nlp-library) (3.5.4)
# Collecting sphinxcontrib-jquery!=3.0.0,>=2.0.0
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->indic-nlp-library) (0.16)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.4)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.2)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.5)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.27.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (67.6.1)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.14.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.2)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (23.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.3->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.26.15)
# Installing collected packages: morfessor, sphinxcontrib-jquery, sphinx-argparse, sphinx-rtd-theme, indic-nlp-library
# Successfully installed indic-nlp-library-0.91 morfessor-2.0.6 sphinx-argparse-0.4.0 sphinx-rtd-theme-1.2.0 sphinxcontrib-jquery-4.1

# %%
from sklearn.model_selection import train_test_split
data = pd.read_csv('/content/gdrive/MyDrive/Hindi AD/new_Manual_dataset.csv')

# %%
data['google_translated_text'] = data[['google_translated_text']].apply(lambda x: x.str.strip()).replace('', np.nan)
data = data.dropna(subset=['google_translated_text'])
data.reset_index(drop=True, inplace=True)

# %%
len(data)
# Out:
# 548

# %%
punctuation_signs = list("?:!.,;|।")
data['google_translated_text'] = data['google_translated_text']

for punct_sign in punctuation_signs:   
    data['google_translated_text'] = data['google_translated_text'].str.replace(punct_sign, '')
# Out:
# <ipython-input-7-ed5fe7e34e63>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['google_translated_text'] = data['google_translated_text'].str.replace(punct_sign, '')

# %%
data['google_translated_text'] = data['google_translated_text'].apply(lambda x: x.replace('\n', ' '))
data['google_translated_text'] = data['google_translated_text'].apply(lambda x: x.replace('\t', ' '))
data['google_translated_text'] = data['google_translated_text'].apply(lambda x: x.replace('।', ' '))
data['google_translated_text'] = data['google_translated_text'].str.replace("    ", " ")
data['google_translated_text'] = data['google_translated_text'].str.replace('"', '')
data['google_translated_text'] = data['google_translated_text'].str.replace("'s", "")
data['google_translated_text'] = data['google_translated_text'].str.replace("।", "")

# %%
data
# Out:
#                                                   text  \
# 0    the scene is in the kitchen.the mother is wipi...
# 1    oh i see the sink is running over . i see the ...
# 2    a boy and a girl are in the kitchen with their...
# 3    okay . it was summertime and mother and the ch...
# 4    wait until i put my glasses on . oh there's a ...
# ..                                                 ...
# 543  well the little kid's falling off his stool . ...
# 544  mhm . well this one is in the cookie jar . and...
# 545  hm  the little boy is on the stool which is ti...
# 546  oh you want me to tell you . the mother and he...
# 547  oh that kid's gonna get a good spill off of th...
#
#                                 google_translated_text  \
# 0    दृश्य रसोई में है माँ व्यंजन पोंछ रही है और पा...
# 1    ओह मुझे लगता है कि सिंक खत्म हो रहा है मुझे लग...
# 2    एक लड़का और एक लड़की अपनी माँ के साथ रसोई में ...
# 3    ठीक है  यह गर्मियों में था और माँ और बच्चे रसो...
# 4    तब तक रुको जब तक मैं अपना चश्मा नहीं डालता ओह ...
# ..                                                 ...
# 543  खैर छोटा बच्चा अपने स्टूल से गिर रहा है और मां...
# 544  एमएचएम खैर यह एक कुकी जार में है और उसने चढ़ने...
# 545  एचएम छोटा लड़का स्टूल पर है जो टिपिंग कर रहा ह...
# 546  ओह आप चाहते हैं कि मैं आपको बताऊं माँ और उसके ...
# 547  ओह कि बच्चे को उस स्टूल से एक अच्छा फैल जाना ह...
#
#                                            mbart50_m2m  \
# 0    दृश्य रसोई में है। मां बर्तन धो रही है और पानी...
# 1    ओह मैं देखता हूँ सिंक ऊपर चल रहा है। मैं देखता...
# 2    एक लड़का और एक लड़की मां के साथ रसोईघर में हैं...
# 3    ठीक है। यह गर्मी का समय था और माँ और बच्चे रसो...
# 4    जब तक मैं अपने चश्मा लगाएं तक प्रतीक्षा करें। ...
# ..                                                 ...
# 543  ठीक है, छोटा बच्चा अपनी कुर्सी से गिर रहा है। ...
# 544  mhm। यह एक कुकी के बर्तन में है। और वो चढ़ने क...
# 545  हां, छोटा लड़का स्टूल पर है जो झुक रहा है और व...
# 546  ओह तुम चाहते हो कि मैं तुम्हें बता दूँ। मां और...
# 547  ओह उस बच्चे को उस स्टूल से अच्छी तरह से बाहर न...
#
#                                           m2m_100_1.2B  \
# 0    दृश्य रसोईघर में है. माँ डिश धो रही है और पानी...
# 1    मैं देखता हूं कि सिंहासन चल रहा है। मैं देखता ...
# 2    एक लड़का और एक लड़की अपनी मां के साथ रसोई में ...
# 3    ठीक है। यह गर्मियों का समय था और माँ और बच्चे ...
# 4    तब तक इंतज़ार करें जब तक मैं अपने चश्मा पहनता ...
# ..                                                 ...
# 543  छोटा बच्चा अपने कुर्सी से गिर रहा है। माँ के प...
# 544  एमएम यह एक कुकी जार में है। और वह चढ़ने की कोश...
# 545  हाँ, छोटा लड़का कुर्सी पर है जो टिपिंग कर रहा ...
# 546  आप चाहते हैं कि मैं आपको बताऊं। मां और उसके दो...
# 547  ओह, उस बच्चे को उस मल से अच्छी तरह से फेंक दिय...
#
#                                                opus-mt    Result  Labels  \
# 0    यह दृश्‍य किचिन में है । एक लड़का एक घड़े से क...   Control       0
# 1    ओह मैं सिंक खत्म हो रहा है देखते हैं. मुझे लगत...   Control       0
# 2    एक लड़का और लड़की रसोई में अपनी माँ के साथ हैं...   Control       0
# 3    ठीक है. गर्मियों का मौसम था और माँ और बच्चे रस...   Control       0
# 4    मैं पर मेरे चश्मा डाल जब तक इंतजार करें. ओह, ए...   Control       0
# ..                                                 ...       ...     ...
# 543  छोटा बच्चा अपनी चौकी से गिर रहा है. और वह (बस्...  Dementia       1
# 544  mh. अच्छी तरह से इस आदमी कुकी जार में है. और व...  Dementia       1
# 545  छोटे लड़के को उस चौकी पर है जिस पर सरकना है और...  Dementia       1
# 546  ओह तुम मुझे तुम्हें बताने के लिए चाहते हैं. मा...  Dementia       1
# 547  ओह है कि बच्चे वहाँ के चारों ओर नहीं बारी है क...  Dementia       1
#
#                                           manual_trans
# 0    दृश्य रसोई की है। माँ बर्तन पोंछ रही है और पान...
# 1    ओह, मैं देख रहा हूँ कि सिंक बह निकला है।मैं दे...
# 2    एक लड़का और एक लड़की रसोई में अपनी माँ के साथ ...
# 3    गर्मी का मौसम था और माँ और बच्चे रसोई में काम ...
# 4    जब तक मैं अपना चश्मा नहीं लगाता तब तक प्रतीक्ष...
# ..                                                 ...
# 543  अच्छ छोटा बच्चा अपने मल से गिर रहा है। और माँ ...
# 544  महम। अच्छा यह कुकी जार में है। और उसने चढ़ने क...
# 545  हम्म छोटा लड़का स्टूल पर है जो ढो रहा है और वह...
# 546  ओह, आप चाहते हैं कि मैं आपको बता दूं। माँ और उ...
# 547  अगर उसकी माँ वहाँ नहीं घूमी और उसे पकड़ नहीं ल...
#
# [548 rows x 8 columns]

# %%
text = data['google_translated_text'].tolist()
clas = data['Labels'].tolist()

data = pd.DataFrame({'text': text, 'target': clas})

# %%
data
# Out:
#                                                   text  target
# 0    दृश्य रसोई में है माँ व्यंजन पोंछ रही है और पा...       0
# 1    ओह मुझे लगता है कि सिंक खत्म हो रहा है मुझे लग...       0
# 2    एक लड़का और एक लड़की अपनी माँ के साथ रसोई में ...       0
# 3    ठीक है  यह गर्मियों में था और माँ और बच्चे रसो...       0
# 4    तब तक रुको जब तक मैं अपना चश्मा नहीं डालता ओह ...       0
# ..                                                 ...     ...
# 543  खैर छोटा बच्चा अपने स्टूल से गिर रहा है और मां...       1
# 544  एमएचएम खैर यह एक कुकी जार में है और उसने चढ़ने...       1
# 545  एचएम छोटा लड़का स्टूल पर है जो टिपिंग कर रहा ह...       1
# 546  ओह आप चाहते हैं कि मैं आपको बताऊं माँ और उसके ...       1
# 547  ओह कि बच्चे को उस स्टूल से एक अच्छा फैल जाना ह...       1
#
# [548 rows x 2 columns]

# %%
# # tokenization
# from indicnlp.tokenize import indic_tokenize
# def tokenization(indic_string):
#     tokens = []
#     for t in indic_tokenize.trivial_tokenize(indic_string):
#         tokens.append(t)
#     return tokens
# data['text'] = data['text'].apply(lambda x: tokenization(x))

# %%
# punctuations = ['nn','n','–', '।','/', '`', '+', '\\', '"', '?', '▁(', '$', '@', '[', '_', "\'", '!', ',', ':', '^', '|', ']', '=', '%', '&', '.', ')', '(', "#", '*', '', ';', '-', '}','|','"']

# stopwords_ni = ['तुम','मेरी','मुझे','क्योंकि','हम','प्रति','अबकी','आगे','माननीय','शहर','बताएं','कौनसी','क्लिक','किसकी','बड़े','मैं','and','रही','आज','लें','आपके','मिलकर','सब','मेरे','जी','श्री','वैसा','आपका','अंदर', 'अत', 'अपना', 
#                 'अपनी', 'अपने', 'अभी', 'आदि', 'आप', 'इत्यादि', 'इन', 'इनका', 'इन्हीं', 'इन्हें', 'इन्हों', 'इस', 'इसका', 'इसकी', 'इसके', 'इसमें', 'इसी', 'इसे', 'उन', 'उनका', 'उनकी', 'उनके', 'उनको', 'उन्हीं', 'उन्हें', 'उन्हों', 'उस', 
#                 'उसके', 'उसी', 'उसे', 'एक', 'एवं', 'एस', 'ऐसे', 'और', 'कई', 'कर','करता', 'करते', 'करना', 'करने', 'करें', 'कहते', 'कहा', 'का', 'काफ़ी', 'कि', 'कितना', 'किन्हें', 'किन्हों', 'किया', 'किर', 'किस', 'किसी', 'किसे', 
#                 'की', 'कुछ', 'कुल', 'के', 'को', 'कोई', 'कौन', 'कौनसा', 'गया', 'घर', 'जब', 'जहाँ', 'जा', 'जितना', 'जिन', 'जिन्हें', 'जिन्हों', 'जिस', 'जिसे', 'जीधर', 'जैसा', 'जैसे', 'जो', 'तक', 'तब', 'तरह', 'तिन', 'तिन्हें', 'तिन्हों',
#                 'तिस', 'तिसे', 'तो', 'था', 'थी', 'थे', 'दबारा', 'दिया', 'दुसरा', 'दूसरे', 'दो', 'द्वारा', 'न', 'नहीं', 'ना', 'निहायत', 'नीचे', 'ने', 'पर', 'पर', 'पहले', 'पूरा', 'पे', 'फिर', 'बनी', 'बही', 'बहुत', 'बाद', 'बाला', 'बिलकुल', 'भी',
#                 'भीतर', 'मगर', 'मानो', 'मे', 'में', 'यदि', 'यह', 'यहाँ', 'यही', 'या', 'यिह', 'ये', 'रखें', 'रहा', 'रहे', 'ऱ्वासा', 'लिए', 'लिये', 'लेकिन', 'व', 'वर्ग', 'वह', 'वह', 'वहाँ', 'वहीं', 'वाले', 'वुह', 'वे', 'वग़ैरह', 'संग', 'सकता', 'सकते',
#                 'सबसे', 'सभी', 'साथ', 'साबुत', 'साभ', 'सारा', 'से', 'सो', 'ही', 'हुआ', 'हुई', 'हुए', 'है', 'हैं', 'हो', 'होता', 'होती', 'होते', 'होना', 'होने', 'अपनि', 'जेसे', 'होति', 'सभि', 'तिंहों', 'इंहों', 'दवारा', 'इसि', 'किंहें', 'थि', 'उंहों', 'ओर', 
#                 'जिंहें', 'वहिं', 'अभि', 'बनि', 'हि', 'उंहिं', 'उंहें', 'हें', 'वगेरह', 'एसे', 'रवासा', 'कोन', 'निचे', 'काफि', 'उसि', 'पुरा', 'भितर', 
#                 'हे', 'बहि', 'वहां', 'कोइ', 'यहां', 'जिंहों', 'तिंहें', 'किसि', 'कइ', 'यहि', 'इंहिं', 'जिधर', 'इंहें', 'अदि', 'इतयादि', 'हुइ', 'कोनसा', 'इसकि', 'दुसरे', 'जहां', 'अप', 'किंहों', 'उनकि', 'भि', 'वरग', 'हुअ', 'जेसा', 'नहिं']
# to_be_removed =  stopwords_ni + punctuations
# # {'पर': 6, 'गर': 4, 'उन': 0, 'एम': 3, 'भन': 7, 'एक': 2, 'सक': 8, 'उव': 1, 'हर': 9, 'छन': 5}

# for i in range(len(data)):
#     data['text'][i]=[ele for ele in data['text'][i] if ele not in (to_be_removed)]
# # count_length()
# data.tail(2)

# %%
# len(stopwords_ni)

# %%
# for i in range(len(data)):
#     data['text'][i] = [s.replace("\n", "") for s in data['text'][i]]

# %%
data
# Out:
#                                                   text  target
# 0    दृश्य रसोई में है माँ व्यंजन पोंछ रही है और पा...       0
# 1    ओह मुझे लगता है कि सिंक खत्म हो रहा है मुझे लग...       0
# 2    एक लड़का और एक लड़की अपनी माँ के साथ रसोई में ...       0
# 3    ठीक है  यह गर्मियों में था और माँ और बच्चे रसो...       0
# 4    तब तक रुको जब तक मैं अपना चश्मा नहीं डालता ओह ...       0
# ..                                                 ...     ...
# 543  खैर छोटा बच्चा अपने स्टूल से गिर रहा है और मां...       1
# 544  एमएचएम खैर यह एक कुकी जार में है और उसने चढ़ने...       1
# 545  एचएम छोटा लड़का स्टूल पर है जो टिपिंग कर रहा ह...       1
# 546  ओह आप चाहते हैं कि मैं आपको बताऊं माँ और उसके ...       1
# 547  ओह कि बच्चे को उस स्टूल से एक अच्छा फैल जाना ह...       1
#
# [548 rows x 2 columns]

# %%
# # #Remove comma as a seperators
# for i in range(len(data)):
#     data['text'][i] = ' '.join(data['text'][i])
# data.tail(2)

# %%
train_df, test_df = train_test_split(data, test_size=0.10, random_state=42, shuffle=True)

# %%
len(train_df)
# Out:
# 493

# %%
len(test_df)
# Out:
# 55

# %%
label_names = ["target"]
y_train = train_df[label_names].values
train_df['doc_len'] = train_df['text'].apply(lambda words: len(words.split(" ")))
max_seq_len = np.round(train_df['doc_len'].mean() + train_df['doc_len'].std()).astype(int)

sns.distplot(train_df['doc_len'], hist=True, kde=True, color='b', label='doc len')
plt.axvline(x=max_seq_len, color='k', linestyle='--', label='max len')
plt.title('comment length'); plt.legend()
plt.show()
# Out:
# <ipython-input-21-89a3e2d80d32>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['doc_len'], hist=True, kde=True, color='b', label='doc len')

# %%
from sklearn.utils import shuffle
from keras.utils import pad_sequences


raw_docs_train = train_df['text'].tolist()
raw_docs_test = test_df['text'].tolist() 
num_classes = len(label_names)

print("pre-processing train data...")

processed_docs_train = []
for doc in tqdm(raw_docs_train):
    tokens = word_tokenize(doc)
    filtered = [word for word in tokens if word not in stop_words]
    processed_docs_train.append(" ".join(filtered))
#end for

processed_docs_test = []
for doc in tqdm(raw_docs_test):
    tokens = word_tokenize(doc)
    filtered = [word for word in tokens if word not in stop_words]
    processed_docs_test.append(" ".join(filtered))
#end for

print("tokenizing input data...")
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, lower=True, char_level=False)
tokenizer.fit_on_texts(processed_docs_train + processed_docs_test)  #leaky
word_seq_train = tokenizer.texts_to_sequences(processed_docs_train)
word_seq_test = tokenizer.texts_to_sequences(processed_docs_test)
word_index = tokenizer.word_index
print("dictionary size: ", len(word_index))

#pad sequences
word_seq_train = pad_sequences(word_seq_train, maxlen=max_seq_len)
word_seq_test = pad_sequences(word_seq_test, maxlen=max_seq_len)
# Out:
# pre-processing train data...
# 100%|██████████| 493/493 [00:00<00:00, 839.34it/s]
# 100%|██████████| 55/55 [00:00<00:00, 1393.03it/s]
# tokenizing input data...
# dictionary size:  1924

# %%
len(word_seq_train)
# Out:
# 493

# %%
len(word_seq_test)
# Out:
# 55

# %%
max_seq_len
# Out:
# 152

# %%
# f = fasttext.load_model('/content/gdrive/MyDrive/pretrained_model/cc.hi.300.bin')


print('loading word embeddings...')

embeddings_index = {}
f = codecs.open('/content/gdrive/MyDrive/pretrained_model/cc.hi.300.vec', encoding='utf-8')

for line in tqdm(f):
    values = line.rstrip().rsplit(' ')
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('found %s word vectors' % len(embeddings_index))
# Out:
# loading word embeddings...
# 1876654it [05:05, 6146.25it/s]
# found 1876654 word vectors

# %%
#training params
batch_size = 128
num_epochs = 20

#model parameters
num_filters = 32 
embed_dim = 300 
weight_decay = 0.97

# %%
#embedding matrix

print('preparing embedding matrix...')

words_not_found = []
nb_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((nb_words, embed_dim))

for word, i in word_index.items():
    if i >= nb_words:
        continue
    embedding_vector = embeddings_index.get(word)
    if (embedding_vector is not None) and len(embedding_vector) > 0:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
    else:
        words_not_found.append(word)
print('number of null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# preparing embedding matrix...
# number of null word embeddings: 81

# %%
print("sample words not found: ", np.random.choice(words_not_found, 10))
# Out:
# sample words not found:  ['स्लेंट' 'क्लियरस्ट्रोट' 'स्पिगोट्स' 'cookeiejark' 'हमहुन' 'फुटस्टूल'
#  'टिल्टी' 'ड्रैप' 'अल्टोफ' 'तिपाया']

# %%
embedding_matrix.shape
# Out:
# (1925, 300)

# %% [markdown]
# ## Bi-LSTM

# %%
model = Sequential()
# model.add(Embedding(nb_words,embed_dim,input_length=max_seq_len, weights=[embedding_matrix],trainable=False))
model.add(Embedding(nb_words,embed_dim,input_length=max_seq_len))
model.add(Bidirectional(LSTM(32 , activation='tanh' ,return_sequences=True ,  input_shape = (140 , 300) ,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(16 , activation = 'tanh', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)  )))
model.add(Dropout(0.3))

model.add(Dense(128 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) ))
model.add(Dropout(0.3))
model.add(Dense(64 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid' ))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 152, 300)          577500
#
#  bidirectional (Bidirectiona  (None, 152, 64)          85248
#  l)
#
#  dropout (Dropout)           (None, 152, 64)           0
#
#  bidirectional_1 (Bidirectio  (None, 32)               10368
#  nal)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 128)               4224
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 685,661
# Trainable params: 685,661
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

from keras.optimizers import SGD,Adam



# opt = Adam(clipvalue=0.5,learning_rate=0.0001)
opt = Adam()
model.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
word_seq_train
# Out:
# array([[   0,    0,    0, ...,    1,   49,   17],
#        [   0,    0,    0, ...,    7,    1,  205],
#        [   0,    0,    0, ...,    2,   34,  171],
#        ...,
#        [   0,    0,    0, ...,   67,   11,    1],
#        [   0,    0,    0, ...,   17, 1857,    1],
#        [  40,   25,   83, ...,   17,   37,   70]], dtype=int32)

# %%
word_seq_train.shape
# Out:
# (493, 152)

# %%
y_train.shape
# Out:
# (493, 1)

# %%
# from imblearn.over_sampling import SMOTE, ADASYN
# X_train, Y_train = SMOTE().fit_resample(word_seq_train, y_train)

# %%
# X_train.shape
# y_train.shape

# %%
# es_callback = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(word_seq_train, y_train , batch_size=256,
          epochs=25, validation_split=0.10, shuffle=False)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 16s 3s/step - loss: 0.8174 - accuracy: 0.5576 - val_loss: 0.8064 - val_accuracy: 0.6000
# Epoch 2/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.8113 - accuracy: 0.5553 - val_loss: 0.7944 - val_accuracy: 0.6000
# Epoch 3/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.8044 - accuracy: 0.5508 - val_loss: 0.7839 - val_accuracy: 0.6000
# Epoch 4/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.7998 - accuracy: 0.5530 - val_loss: 0.7754 - val_accuracy: 0.6000
# Epoch 5/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.8027 - accuracy: 0.5508 - val_loss: 0.7699 - val_accuracy: 0.6000
# Epoch 6/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.7896 - accuracy: 0.5688 - val_loss: 0.7648 - val_accuracy: 0.6000
# Epoch 7/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.7830 - accuracy: 0.5779 - val_loss: 0.7591 - val_accuracy: 0.6400
# Epoch 8/25
# 2/2 [==============================] - 3s 1s/step - loss: 0.7757 - accuracy: 0.5982 - val_loss: 0.7514 - val_accuracy: 0.6600
# Epoch 9/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.7543 - accuracy: 0.6321 - val_loss: 0.7381 - val_accuracy: 0.6600
# Epoch 10/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.7273 - accuracy: 0.6546 - val_loss: 0.7173 - val_accuracy: 0.7000
# Epoch 11/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.6982 - accuracy: 0.7065 - val_loss: 0.6939 - val_accuracy: 0.7000
# Epoch 12/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.6467 - accuracy: 0.8014 - val_loss: 0.6706 - val_accuracy: 0.7200
# Epoch 13/25
# 2/2 [==============================] - 3s 1s/step - loss: 0.5906 - accuracy: 0.8555 - val_loss: 0.6535 - val_accuracy: 0.7000
# Epoch 14/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.5161 - accuracy: 0.8804 - val_loss: 0.6584 - val_accuracy: 0.6800
# Epoch 15/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.4465 - accuracy: 0.8962 - val_loss: 0.6931 - val_accuracy: 0.6600
# Epoch 16/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.3848 - accuracy: 0.9187 - val_loss: 0.7591 - val_accuracy: 0.6600
# Epoch 17/25
# 2/2 [==============================] - 3s 2s/step - loss: 0.3343 - accuracy: 0.9323 - val_loss: 0.8339 - val_accuracy: 0.6600
# Epoch 18/25
# 2/2 [==============================] - 4s 1s/step - loss: 0.2856 - accuracy: 0.9503 - val_loss: 1.0025 - val_accuracy: 0.7000
# Epoch 19/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.2471 - accuracy: 0.9594 - val_loss: 1.0436 - val_accuracy: 0.7000
# Epoch 20/25
# 2/2 [==============================] - 3s 1s/step - loss: 0.2224 - accuracy: 0.9639 - val_loss: 1.1115 - val_accuracy: 0.6800
# Epoch 21/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.2250 - accuracy: 0.9684 - val_loss: 1.2800 - val_accuracy: 0.7000
# Epoch 22/25
# 2/2 [==============================] - 4s 2s/step - loss: 0.1828 - accuracy: 0.9774 - val_loss: 1.3736 - val_accuracy: 0.7200
# Epoch 23/25
# 2/2 [==============================] - 3s 1s/step - loss: 0.1623 - accuracy: 0.9797 - val_loss: 1.5789 - val_accuracy: 0.6400
# Epoch 24/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.1737 - accuracy: 0.9707 - val_loss: 1.6115 - val_accuracy: 0.6800
# Epoch 25/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.1623 - accuracy: 0.9774 - val_loss: 1.6630 - val_accuracy: 0.6800

# %%
# #generate plots
# plt.figure()
# plt.plot(history.history['loss'], lw=2.0, color='b', label='train')
# plt.plot(history.history['val_loss'], lw=2.0, color='r', label='val')
# plt.title('LSTM sentiment')
# plt.xlabel('Epochs')
# plt.ylabel('Cross-Entropy Loss')
# plt.legend(loc='upper right')
# plt.show()

# %%
# plt.figure()
# plt.plot(history.history['accuracy'], lw=2.0, color='b', label='train')
# plt.plot(history.history['val_accuracy'], lw=2.0, color='r', label='val')
# plt.title('LSTM sentiment')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend(loc='upper left')
# plt.show()

# %%
predictions = model.predict(word_seq_test)
# predictions= predictions.ravel()

# sample=pd.read_csv('test_dat.csv')
test_df['pred']= (predictions>0.5).astype(int)
test_df[['pred', "target"]]
# Out:
# 2/2 [==============================] - 2s 93ms/step
#      pred  target
# 247     1       1
# 78      1       0
# 245     1       1
# 353     1       1
# 477     1       1
# 541     0       1
# 335     1       1
# 319     1       1
# 250     1       1
# 82      0       0
# 432     1       1
# 6       1       0
# 287     0       1
# 101     0       0
# 526     1       1
# 220     0       0
# 393     1       1
# 502     0       1
# 318     1       1
# 104     1       0
# 425     0       1
# 375     1       1
# 352     0       1
# 307     1       1
# 76      0       0
# 268     1       1
# 2       1       0
# 55      0       0
# 77      0       0
# 10      0       0
# 73      0       0
# 543     1       1
# 192     1       0
# 382     1       1
# 476     1       1
# 90      0       0
# 362     1       1
# 148     0       0
# 462     1       1
# 469     1       1
# 210     0       0
# 278     1       1
# 165     1       0
# 172     0       0
# 184     0       0
# 515     1       1
# 368     0       1
# 72      1       0
# 84      0       0
# 434     1       1
# 534     1       1
# 519     1       1
# 30      0       0
# 167     0       0
# 86      0       0

# %%
predictions.shape
# Out:
# (55, 1)

# %%
word_seq_test.shape
# Out:
# (55, 152)

# %%
test_df[["target"]].shape
# Out:
# (55, 1)

# %%
predictions.shape
# Out:
# (55, 1)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from imblearn.metrics import macro_averaged_mean_absolute_error

print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
print(confusion_matrix(test_df.target, test_df.pred))
# Out:
# Accuracy ->  0.7636363636363637
# Recall ->  0.7573924731182795
# Precision ->  0.7601902173913043
# F1 score ->  0.7585275244849713
# Macro MAE ->  0.24260752688172044
# [[17  7]
#  [ 6 25]]

# %% [markdown]
# ## LSTM

# %%
nb_words
# Out:
# 1848

# %%
embed_dim
# Out:
# 300

# %%
max_seq_len
# Out:
# 64

# %%
word_seq_train.shape
# Out:
# (492, 64)

# %%
  model = Sequential()
  model.add(Embedding(nb_words,embed_dim,input_length=max_seq_len))
  model.add((LSTM(16 , activation='tanh' ,return_sequences=True ,  input_shape = (140 , 300) ,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))
  model.add(Dropout(0.3))

  model.add((LSTM(16 , activation = 'tanh',return_sequences=True, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)  )))
  model.add((LSTM(8 , activation = 'tanh', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))

  model.add(Dropout(0.3))
  
  model.add(Dense(128 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) ))
  model.add(Dropout(0.3))
  model.add(Dense(64 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
  model.add(Dense(1, activation='sigmoid' ))
  model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 152, 300)          577500
#
#  lstm_9 (LSTM)               (None, 152, 16)           20288
#
#  dropout_8 (Dropout)         (None, 152, 16)           0
#
#  lstm_10 (LSTM)              (None, 152, 16)           2112
#
#  lstm_11 (LSTM)              (None, 8)                 800
#
#  dropout_9 (Dropout)         (None, 8)                 0
#
#  dense_9 (Dense)             (None, 128)               1152
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 610,173
# Trainable params: 610,173
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

from keras.optimizers import SGD,Adam



# opt = Adam(clipvalue=0.5,learning_rate=0.0001)
opt = Adam()
model.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# es_callback = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(word_seq_train, y_train , batch_size=32,
          epochs=25, validation_split=0.10, shuffle=False)
# Out:
# Epoch 1/25
# 14/14 [==============================] - 19s 474ms/step - loss: 0.7367 - accuracy: 0.5102 - val_loss: 0.7288 - val_accuracy: 0.6000
# Epoch 2/25
# 14/14 [==============================] - 4s 283ms/step - loss: 0.7246 - accuracy: 0.5508 - val_loss: 0.7098 - val_accuracy: 0.6000
# Epoch 3/25
# 14/14 [==============================] - 4s 263ms/step - loss: 0.6986 - accuracy: 0.5508 - val_loss: 0.6553 - val_accuracy: 0.6200
# Epoch 4/25
# 14/14 [==============================] - 5s 345ms/step - loss: 0.5635 - accuracy: 0.7517 - val_loss: 0.5721 - val_accuracy: 0.7000
# Epoch 5/25
# 14/14 [==============================] - 5s 334ms/step - loss: 0.3711 - accuracy: 0.8894 - val_loss: 0.6221 - val_accuracy: 0.7400
# Epoch 6/25
# 14/14 [==============================] - 4s 253ms/step - loss: 0.2109 - accuracy: 0.9300 - val_loss: 0.8223 - val_accuracy: 0.7000
# Epoch 7/25
# 14/14 [==============================] - 3s 245ms/step - loss: 0.2812 - accuracy: 0.9142 - val_loss: 1.3384 - val_accuracy: 0.6600
# Epoch 8/25
# 14/14 [==============================] - 5s 344ms/step - loss: 0.3207 - accuracy: 0.8849 - val_loss: 0.7144 - val_accuracy: 0.6800
# Epoch 9/25
# 14/14 [==============================] - 4s 274ms/step - loss: 0.1687 - accuracy: 0.9571 - val_loss: 0.8653 - val_accuracy: 0.7000
# Epoch 10/25
# 14/14 [==============================] - 3s 249ms/step - loss: 0.0939 - accuracy: 0.9887 - val_loss: 0.9758 - val_accuracy: 0.6800
# Epoch 11/25
# 14/14 [==============================] - 3s 246ms/step - loss: 0.0644 - accuracy: 0.9955 - val_loss: 1.2424 - val_accuracy: 0.7000
# Epoch 12/25
# 14/14 [==============================] - 5s 389ms/step - loss: 0.0531 - accuracy: 0.9932 - val_loss: 1.3572 - val_accuracy: 0.6800
# Epoch 13/25
# 14/14 [==============================] - 3s 246ms/step - loss: 0.0449 - accuracy: 0.9955 - val_loss: 1.3779 - val_accuracy: 0.6800
# Epoch 14/25
# 14/14 [==============================] - 3s 243ms/step - loss: 0.0328 - accuracy: 0.9977 - val_loss: 1.4633 - val_accuracy: 0.6600
# Epoch 15/25
# 14/14 [==============================] - 3s 251ms/step - loss: 0.0339 - accuracy: 0.9977 - val_loss: 1.4677 - val_accuracy: 0.7200
# Epoch 16/25
# 14/14 [==============================] - 5s 346ms/step - loss: 0.0325 - accuracy: 0.9977 - val_loss: 1.5733 - val_accuracy: 0.7000
# Epoch 17/25
# 14/14 [==============================] - 3s 242ms/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 1.7849 - val_accuracy: 0.6800
# Epoch 18/25
# 14/14 [==============================] - 3s 241ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 1.8129 - val_accuracy: 0.6800
# Epoch 19/25
# 14/14 [==============================] - 4s 265ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 1.8209 - val_accuracy: 0.6800
# Epoch 20/25
# 14/14 [==============================] - 5s 348ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 1.8512 - val_accuracy: 0.6800
# Epoch 21/25
# 14/14 [==============================] - 4s 251ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 1.8899 - val_accuracy: 0.6600
# Epoch 22/25
# 14/14 [==============================] - 3s 246ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 1.9325 - val_accuracy: 0.6600
# Epoch 23/25
# 14/14 [==============================] - 4s 307ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 1.9575 - val_accuracy: 0.6600
# Epoch 24/25
# 14/14 [==============================] - 4s 307ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 1.9756 - val_accuracy: 0.6800
# Epoch 25/25
# 14/14 [==============================] - 3s 243ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 1.9968 - val_accuracy: 0.6800

# %%
# #generate plots
# plt.figure()
# plt.plot(history.history['loss'], lw=2.0, color='b', label='train')
# plt.plot(history.history['val_loss'], lw=2.0, color='r', label='val')
# plt.title('LSTM sentiment')
# plt.xlabel('Epochs')
# plt.ylabel('Cross-Entropy Loss')
# plt.legend(loc='upper right')
# plt.show()

# %%
# plt.figure()
# plt.plot(history.history['accuracy'], lw=2.0, color='b', label='train')
# plt.plot(history.history['val_accuracy'], lw=2.0, color='r', label='val')
# plt.title('LSTM sentiment')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend(loc='upper left')
# plt.show()

# %%
predictions = model.predict(word_seq_test)
# predictions= predictions.ravel()

# sample=pd.read_csv('test_dat.csv')
test_df['pred']= (predictions>0.5).astype(int)
test_df[['pred', "target"]]
# Out:
# 2/2 [==============================] - 2s 43ms/step
#      pred  target
# 247     1       1
# 78      0       0
# 245     1       1
# 353     1       1
# 477     1       1
# 541     0       1
# 335     1       1
# 319     1       1
# 250     0       1
# 82      0       0
# 432     1       1
# 6       1       0
# 287     1       1
# 101     0       0
# 526     1       1
# 220     0       0
# 393     1       1
# 502     0       1
# 318     1       1
# 104     1       0
# 425     0       1
# 375     1       1
# 352     0       1
# 307     1       1
# 76      0       0
# 268     1       1
# 2       0       0
# 55      0       0
# 77      0       0
# 10      0       0
# 73      0       0
# 543     1       1
# 192     1       0
# 382     0       1
# 476     1       1
# 90      0       0
# 362     1       1
# 148     0       0
# 462     1       1
# 469     1       1
# 210     0       0
# 278     1       1
# 165     1       0
# 172     0       0
# 184     0       0
# 515     1       1
# 368     0       1
# 72      0       0
# 84      0       0
# 434     0       1
# 534     1       1
# 519     1       1
# 30      0       0
# 167     0       0
# 86      0       0

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from imblearn.metrics import macro_averaged_mean_absolute_error

print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
print(confusion_matrix(test_df.target, test_df.pred))
# Out:
# Accuracy ->  0.7818181818181819
# Recall ->  0.7876344086021505
# Precision ->  0.783068783068783
# F1 score ->  0.7811671087533156
# Macro MAE ->  0.21236559139784944
# [[20  4]
#  [ 8 23]]

# %% [markdown]
# ## CNN+LSTM

# %%
model = Sequential()
model.add(Embedding(1848,300,input_length=max_seq_len))

# model.add((Conv1D(16,(3) , activation='tanh' ,return_sequences=True ,  input_shape = (140 , 300) ,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))


model.add(Conv1D(8,(3),activation = 'tanh',kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) ))

model.add(MaxPool1D(3))

# model.add(Bidirectional(LSTM(8,return_sequences=True,activation='tanh',kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)  )))
model.add(Dropout(0.2))
# model.add(BatchNormalization())
model.add(Bidirectional(LSTM(8,activation='tanh',kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))


model.add(Dense(128 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model.add(Dropout(0.4))
model.add(Dense(32 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model.add(Dense(1, activation='sigmoid' ))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 64, 300)           554400
#
#  conv1d_7 (Conv1D)           (None, 62, 8)             7208
#
#  max_pooling1d_6 (MaxPooling  (None, 20, 8)            0
#  1D)
#
#  dropout_12 (Dropout)        (None, 20, 8)             0
#
#  bidirectional_10 (Bidirecti  (None, 16)               1088
#  onal)
#
#  dense_15 (Dense)            (None, 128)               2176
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 32)                4128
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 569,033
# Trainable params: 569,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

from keras.optimizers import SGD,Adam



# opt = Adam(clipvalue=0.5,learning_rate=0.0001)
opt = Adam(learning_rate=0.0001)
model.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# es_callback = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(word_seq_train, y_train , batch_size=256,
          epochs=25, validation_split=0.10, shuffle=False)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 8s 2s/step - loss: 0.7147 - accuracy: 0.5566 - val_loss: 0.7139 - val_accuracy: 0.6000
# Epoch 2/25
# 2/2 [==============================] - 1s 219ms/step - loss: 0.7144 - accuracy: 0.5385 - val_loss: 0.7129 - val_accuracy: 0.6000
# Epoch 3/25
# 2/2 [==============================] - 0s 187ms/step - loss: 0.7131 - accuracy: 0.5498 - val_loss: 0.7119 - val_accuracy: 0.6000
# Epoch 4/25
# 2/2 [==============================] - 0s 169ms/step - loss: 0.7132 - accuracy: 0.5452 - val_loss: 0.7109 - val_accuracy: 0.6000
# Epoch 5/25
# 2/2 [==============================] - 0s 175ms/step - loss: 0.7132 - accuracy: 0.5452 - val_loss: 0.7100 - val_accuracy: 0.6000
# Epoch 6/25
# 2/2 [==============================] - 0s 180ms/step - loss: 0.7127 - accuracy: 0.5475 - val_loss: 0.7090 - val_accuracy: 0.6000
# Epoch 7/25
# 2/2 [==============================] - 0s 187ms/step - loss: 0.7119 - accuracy: 0.5475 - val_loss: 0.7081 - val_accuracy: 0.6000
# Epoch 8/25
# 2/2 [==============================] - 0s 197ms/step - loss: 0.7117 - accuracy: 0.5475 - val_loss: 0.7071 - val_accuracy: 0.6000
# Epoch 9/25
# 2/2 [==============================] - 0s 192ms/step - loss: 0.7107 - accuracy: 0.5475 - val_loss: 0.7062 - val_accuracy: 0.6000
# Epoch 10/25
# 2/2 [==============================] - 0s 200ms/step - loss: 0.7110 - accuracy: 0.5475 - val_loss: 0.7052 - val_accuracy: 0.6000
# Epoch 11/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.7097 - accuracy: 0.5475 - val_loss: 0.7042 - val_accuracy: 0.6000
# Epoch 12/25
# 2/2 [==============================] - 0s 173ms/step - loss: 0.7095 - accuracy: 0.5475 - val_loss: 0.7031 - val_accuracy: 0.6000
# Epoch 13/25
# 2/2 [==============================] - 0s 179ms/step - loss: 0.7095 - accuracy: 0.5475 - val_loss: 0.7021 - val_accuracy: 0.6000
# Epoch 14/25
# 2/2 [==============================] - 0s 200ms/step - loss: 0.7072 - accuracy: 0.5475 - val_loss: 0.7011 - val_accuracy: 0.6000
# Epoch 15/25
# 2/2 [==============================] - 0s 174ms/step - loss: 0.7088 - accuracy: 0.5475 - val_loss: 0.7001 - val_accuracy: 0.6000
# Epoch 16/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.7065 - accuracy: 0.5475 - val_loss: 0.6991 - val_accuracy: 0.6000
# Epoch 17/25
# 2/2 [==============================] - 0s 187ms/step - loss: 0.7067 - accuracy: 0.5475 - val_loss: 0.6981 - val_accuracy: 0.6000
# Epoch 18/25
# 2/2 [==============================] - 0s 174ms/step - loss: 0.7060 - accuracy: 0.5475 - val_loss: 0.6971 - val_accuracy: 0.6000
# Epoch 19/25
# 2/2 [==============================] - 0s 182ms/step - loss: 0.7045 - accuracy: 0.5475 - val_loss: 0.6961 - val_accuracy: 0.6000
# Epoch 20/25
# 2/2 [==============================] - 0s 193ms/step - loss: 0.7048 - accuracy: 0.5475 - val_loss: 0.6950 - val_accuracy: 0.6000
# Epoch 21/25
# 2/2 [==============================] - 0s 192ms/step - loss: 0.7049 - accuracy: 0.5475 - val_loss: 0.6940 - val_accuracy: 0.6000
# Epoch 22/25
# 2/2 [==============================] - 0s 198ms/step - loss: 0.7037 - accuracy: 0.5475 - val_loss: 0.6930 - val_accuracy: 0.6000
# Epoch 23/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.7031 - accuracy: 0.5475 - val_loss: 0.6920 - val_accuracy: 0.6000
# Epoch 24/25
# 2/2 [==============================] - 0s 206ms/step - loss: 0.7025 - accuracy: 0.5543 - val_loss: 0.6910 - val_accuracy: 0.6000
# Epoch 25/25
# 2/2 [==============================] - 0s 171ms/step - loss: 0.7020 - accuracy: 0.5498 - val_loss: 0.6900 - val_accuracy: 0.6000

# %%
#generate plots
plt.figure()
plt.plot(history.history['loss'], lw=2.0, color='b', label='train')
plt.plot(history.history['val_loss'], lw=2.0, color='r', label='val')
plt.title('LSTM sentiment')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure()
plt.plot(history.history['accuracy'], lw=2.0, color='b', label='train')
plt.plot(history.history['val_accuracy'], lw=2.0, color='r', label='val')
plt.title('LSTM sentiment')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
predictions = model.predict(word_seq_test)
# predictions= predictions.ravel()

# sample=pd.read_csv('test_dat.csv')
test_df['pred']= (predictions>0.5).astype(int)
test_df[['pred', "target"]]
# Out:
# 2/2 [==============================] - 1s 13ms/step
#      pred  target
# 176     1       0
# 77      1       0
# 361     1       1
# 90      1       0
# 368     1       1
# 210     1       0
# 177     1       0
# 250     1       1
# 518     1       1
# 199     1       0
# 6       1       0
# 354     1       1
# 424     1       1
# 261     1       1
# 247     1       1
# 316     1       1
# 501     1       1
# 55      1       0
# 470     1       1
# 499     1       1
# 72      1       0
# 440     1       1
# 540     1       1
# 225     1       0
# 312     1       1
# 2       1       0
# 388     1       1
# 185     1       0
# 10      1       0
# 163     1       0
# 70      1       0
# 286     1       1
# 79      1       0
# 395     1       1
# 396     1       1
# 469     1       1
# 211     1       0
# 433     1       1
# 514     1       1
# 277     1       1
# 158     1       0
# 431     1       1
# 76      1       0
# 297     1       1
# 367     1       1
# 403     1       1
# 83      1       0
# 137     1       0
# 426     1       1
# 542     1       1
# 30      1       0
# 477     1       1
# 398     1       1
# 325     1       1
# 192     1       0

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from imblearn.metrics import macro_averaged_mean_absolute_error

print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
print(confusion_matrix(test_df.target, test_df.pred))
# Out:
# Accuracy ->  0.5818181818181818
# Recall ->  0.5
# Precision ->  0.2909090909090909
# F1 score ->  0.367816091954023
# Macro MAE ->  0.5
# [[ 0 23]
#  [ 0 32]]
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
