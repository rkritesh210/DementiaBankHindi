# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
#For Pre-Processing
from tqdm import tqdm
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import RegexpTokenizer 
from nltk.tokenize import word_tokenize
import os, re, csv, math, codecs


# For Training
import keras
from keras import optimizers
from keras import backend as K
from keras import regularizers

from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Model,Sequential

# For array, dataset, and visualizing
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
np.random.seed(0)

MAX_NB_WORDS = 100000
tokenizer = RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))
stop_words.update(['।','.', ',', '"', "'", ':', ';', '(', ')', '[', ']', '{', '}'])




from sklearn.model_selection import train_test_split , LeaveOneOut
import pandas as pd
import numpy as np
np.random.seed(5)
import os
import keras.regularizers as regular
from keras.layers import Input, Dense,Conv1D,LSTM,GRU, Dropout, Flatten, Concatenate, MaxPool1D, Embedding, TimeDistributed, Bidirectional,Add, BatchNormalization
from keras.models import Model,Sequential
from keras import regularizers
import keras
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from tensorflow.keras.layers import Conv2D
from sklearn.metrics import mean_absolute_error
from imblearn.metrics import macro_averaged_mean_absolute_error
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !pip install indic-nlp-library

# %%
from sklearn.model_selection import train_test_split
data = pd.read_csv('/content/gdrive/MyDrive/Hindi AD/new_Manual_dataset.csv')

# %%
data
# Out:
#                                                   text  \
# 0    the scene is in the kitchen.the mother is wipi...
# 1    oh i see the sink is running over . i see the ...
# 2    a boy and a girl are in the kitchen with their...
# 3    okay . it was summertime and mother and the ch...
# 4    wait until i put my glasses on . oh there's a ...
# ..                                                 ...
# 543  well the little kid's falling off his stool . ...
# 544  mhm . well this one is in the cookie jar . and...
# 545  hm  the little boy is on the stool which is ti...
# 546  oh you want me to tell you . the mother and he...
# 547  oh that kid's gonna get a good spill off of th...
#
#                                 google_translated_text  \
# 0    दृश्य रसोई में है। माँ व्यंजन पोंछ रही है और प...
# 1    ओह, मुझे लगता है कि सिंक खत्म हो रहा है। मुझे ...
# 2    एक लड़का और एक लड़की अपनी माँ के साथ रसोई में ...
# 3    ठीक है । यह गर्मियों में था और माँ और बच्चे रस...
# 4    तब तक रुको जब तक मैं अपना चश्मा नहीं डालता। ओह...
# ..                                                 ...
# 543  खैर छोटा बच्चा अपने स्टूल से गिर रहा है। और मा...
# 544  एमएचएम। खैर यह एक कुकी जार में है। और उसने चढ़...
# 545  एचएम छोटा लड़का स्टूल पर है जो टिपिंग कर रहा ह...
# 546  ओह, आप चाहते हैं कि मैं आपको बताऊं। माँ और उसक...
# 547  ओह, कि बच्चे को उस स्टूल से एक अच्छा फैल जाना ...
#
#                                            mbart50_m2m  \
# 0    दृश्य रसोई में है। मां बर्तन धो रही है और पानी...
# 1    ओह मैं देखता हूँ सिंक ऊपर चल रहा है। मैं देखता...
# 2    एक लड़का और एक लड़की मां के साथ रसोईघर में हैं...
# 3    ठीक है। यह गर्मी का समय था और माँ और बच्चे रसो...
# 4    जब तक मैं अपने चश्मा लगाएं तक प्रतीक्षा करें। ...
# ..                                                 ...
# 543  ठीक है, छोटा बच्चा अपनी कुर्सी से गिर रहा है। ...
# 544  mhm। यह एक कुकी के बर्तन में है। और वो चढ़ने क...
# 545  हां, छोटा लड़का स्टूल पर है जो झुक रहा है और व...
# 546  ओह तुम चाहते हो कि मैं तुम्हें बता दूँ। मां और...
# 547  ओह उस बच्चे को उस स्टूल से अच्छी तरह से बाहर न...
#
#                                           m2m_100_1.2B  \
# 0    दृश्य रसोईघर में है. माँ डिश धो रही है और पानी...
# 1    मैं देखता हूं कि सिंहासन चल रहा है। मैं देखता ...
# 2    एक लड़का और एक लड़की अपनी मां के साथ रसोई में ...
# 3    ठीक है। यह गर्मियों का समय था और माँ और बच्चे ...
# 4    तब तक इंतज़ार करें जब तक मैं अपने चश्मा पहनता ...
# ..                                                 ...
# 543  छोटा बच्चा अपने कुर्सी से गिर रहा है। माँ के प...
# 544  एमएम यह एक कुकी जार में है। और वह चढ़ने की कोश...
# 545  हाँ, छोटा लड़का कुर्सी पर है जो टिपिंग कर रहा ...
# 546  आप चाहते हैं कि मैं आपको बताऊं। मां और उसके दो...
# 547  ओह, उस बच्चे को उस मल से अच्छी तरह से फेंक दिय...
#
#                                                opus-mt    Result  Labels  \
# 0    यह दृश्‍य किचिन में है । एक लड़का एक घड़े से क...   Control       0
# 1    ओह मैं सिंक खत्म हो रहा है देखते हैं. मुझे लगत...   Control       0
# 2    एक लड़का और लड़की रसोई में अपनी माँ के साथ हैं...   Control       0
# 3    ठीक है. गर्मियों का मौसम था और माँ और बच्चे रस...   Control       0
# 4    मैं पर मेरे चश्मा डाल जब तक इंतजार करें. ओह, ए...   Control       0
# ..                                                 ...       ...     ...
# 543  छोटा बच्चा अपनी चौकी से गिर रहा है. और वह (बस्...  Dementia       1
# 544  mh. अच्छी तरह से इस आदमी कुकी जार में है. और व...  Dementia       1
# 545  छोटे लड़के को उस चौकी पर है जिस पर सरकना है और...  Dementia       1
# 546  ओह तुम मुझे तुम्हें बताने के लिए चाहते हैं. मा...  Dementia       1
# 547  ओह है कि बच्चे वहाँ के चारों ओर नहीं बारी है क...  Dementia       1
#
#                                           manual_trans
# 0    दृश्य रसोई की है। माँ बर्तन पोंछ रही है और पान...
# 1    ओह, मैं देख रहा हूँ कि सिंक बह निकला है।मैं दे...
# 2    एक लड़का और एक लड़की रसोई में अपनी माँ के साथ ...
# 3    गर्मी का मौसम था और माँ और बच्चे रसोई में काम ...
# 4    जब तक मैं अपना चश्मा नहीं लगाता तब तक प्रतीक्ष...
# ..                                                 ...
# 543  अच्छ छोटा बच्चा अपने मल से गिर रहा है। और माँ ...
# 544  महम। अच्छा यह कुकी जार में है। और उसने चढ़ने क...
# 545  हम्म छोटा लड़का स्टूल पर है जो ढो रहा है और वह...
# 546  ओह, आप चाहते हैं कि मैं आपको बता दूं। माँ और उ...
# 547  अगर उसकी माँ वहाँ नहीं घूमी और उसे पकड़ नहीं ल...
#
# [548 rows x 8 columns]

# %%
data['m2m_100_1.2B'] = data[['m2m_100_1.2B']].apply(lambda x: x.str.strip()).replace('', np.nan)
data = data.dropna(subset=['m2m_100_1.2B'])
data.reset_index(drop=True, inplace=True)

# %%
len(data)
# Out:
# 548

# %%
punctuation_signs = list("?:!.,;|।")
data['m2m_100_1.2B'] = data['m2m_100_1.2B']

for punct_sign in punctuation_signs:   
    data['m2m_100_1.2B'] = data['m2m_100_1.2B'].str.replace(punct_sign, '')
# Out:
# <ipython-input-8-dc3d79b3f6cc>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['m2m_100_1.2B'] = data['m2m_100_1.2B'].str.replace(punct_sign, '')

# %%
data['m2m_100_1.2B'] = data['m2m_100_1.2B'].apply(lambda x: x.replace('\n', ' '))
data['m2m_100_1.2B'] = data['m2m_100_1.2B'].apply(lambda x: x.replace('\t', ' '))
data['m2m_100_1.2B'] = data['m2m_100_1.2B'].apply(lambda x: x.replace('।', ' '))
data['m2m_100_1.2B'] = data['m2m_100_1.2B'].str.replace("    ", " ")
data['m2m_100_1.2B'] = data['m2m_100_1.2B'].str.replace('"', '')
data['m2m_100_1.2B'] = data['m2m_100_1.2B'].str.replace("'s", "")
data['m2m_100_1.2B'] = data['m2m_100_1.2B'].str.replace("।", "")

# %%
data
# Out:
#                                                   text  \
# 0    the scene is in the kitchen.the mother is wipi...
# 1    oh i see the sink is running over . i see the ...
# 2    a boy and a girl are in the kitchen with their...
# 3    okay . it was summertime and mother and the ch...
# 4    wait until i put my glasses on . oh there's a ...
# ..                                                 ...
# 543  well the little kid's falling off his stool . ...
# 544  mhm . well this one is in the cookie jar . and...
# 545  hm  the little boy is on the stool which is ti...
# 546  oh you want me to tell you . the mother and he...
# 547  oh that kid's gonna get a good spill off of th...
#
#                                 google_translated_text  \
# 0    दृश्य रसोई में है। माँ व्यंजन पोंछ रही है और प...
# 1    ओह, मुझे लगता है कि सिंक खत्म हो रहा है। मुझे ...
# 2    एक लड़का और एक लड़की अपनी माँ के साथ रसोई में ...
# 3    ठीक है । यह गर्मियों में था और माँ और बच्चे रस...
# 4    तब तक रुको जब तक मैं अपना चश्मा नहीं डालता। ओह...
# ..                                                 ...
# 543  खैर छोटा बच्चा अपने स्टूल से गिर रहा है। और मा...
# 544  एमएचएम। खैर यह एक कुकी जार में है। और उसने चढ़...
# 545  एचएम छोटा लड़का स्टूल पर है जो टिपिंग कर रहा ह...
# 546  ओह, आप चाहते हैं कि मैं आपको बताऊं। माँ और उसक...
# 547  ओह, कि बच्चे को उस स्टूल से एक अच्छा फैल जाना ...
#
#                                            mbart50_m2m  \
# 0    दृश्य रसोई में है। मां बर्तन धो रही है और पानी...
# 1    ओह मैं देखता हूँ सिंक ऊपर चल रहा है। मैं देखता...
# 2    एक लड़का और एक लड़की मां के साथ रसोईघर में हैं...
# 3    ठीक है। यह गर्मी का समय था और माँ और बच्चे रसो...
# 4    जब तक मैं अपने चश्मा लगाएं तक प्रतीक्षा करें। ...
# ..                                                 ...
# 543  ठीक है, छोटा बच्चा अपनी कुर्सी से गिर रहा है। ...
# 544  mhm। यह एक कुकी के बर्तन में है। और वो चढ़ने क...
# 545  हां, छोटा लड़का स्टूल पर है जो झुक रहा है और व...
# 546  ओह तुम चाहते हो कि मैं तुम्हें बता दूँ। मां और...
# 547  ओह उस बच्चे को उस स्टूल से अच्छी तरह से बाहर न...
#
#                                           m2m_100_1.2B  \
# 0    दृश्य रसोईघर में है माँ डिश धो रही है और पानी ...
# 1    मैं देखता हूं कि सिंहासन चल रहा है मैं देखता ह...
# 2    एक लड़का और एक लड़की अपनी मां के साथ रसोई में ...
# 3    ठीक है यह गर्मियों का समय था और माँ और बच्चे र...
# 4    तब तक इंतज़ार करें जब तक मैं अपने चश्मा पहनता ...
# ..                                                 ...
# 543  छोटा बच्चा अपने कुर्सी से गिर रहा है माँ के पा...
# 544  एमएम यह एक कुकी जार में है और वह चढ़ने की कोशि...
# 545  हाँ छोटा लड़का कुर्सी पर है जो टिपिंग कर रहा ह...
# 546  आप चाहते हैं कि मैं आपको बताऊं मां और उसके दो ...
# 547  ओह उस बच्चे को उस मल से अच्छी तरह से फेंक दिया...
#
#                                                opus-mt    Result  Labels  \
# 0    यह दृश्‍य किचिन में है । एक लड़का एक घड़े से क...   Control       0
# 1    ओह मैं सिंक खत्म हो रहा है देखते हैं. मुझे लगत...   Control       0
# 2    एक लड़का और लड़की रसोई में अपनी माँ के साथ हैं...   Control       0
# 3    ठीक है. गर्मियों का मौसम था और माँ और बच्चे रस...   Control       0
# 4    मैं पर मेरे चश्मा डाल जब तक इंतजार करें. ओह, ए...   Control       0
# ..                                                 ...       ...     ...
# 543  छोटा बच्चा अपनी चौकी से गिर रहा है. और वह (बस्...  Dementia       1
# 544  mh. अच्छी तरह से इस आदमी कुकी जार में है. और व...  Dementia       1
# 545  छोटे लड़के को उस चौकी पर है जिस पर सरकना है और...  Dementia       1
# 546  ओह तुम मुझे तुम्हें बताने के लिए चाहते हैं. मा...  Dementia       1
# 547  ओह है कि बच्चे वहाँ के चारों ओर नहीं बारी है क...  Dementia       1
#
#                                           manual_trans
# 0    दृश्य रसोई की है। माँ बर्तन पोंछ रही है और पान...
# 1    ओह, मैं देख रहा हूँ कि सिंक बह निकला है।मैं दे...
# 2    एक लड़का और एक लड़की रसोई में अपनी माँ के साथ ...
# 3    गर्मी का मौसम था और माँ और बच्चे रसोई में काम ...
# 4    जब तक मैं अपना चश्मा नहीं लगाता तब तक प्रतीक्ष...
# ..                                                 ...
# 543  अच्छ छोटा बच्चा अपने मल से गिर रहा है। और माँ ...
# 544  महम। अच्छा यह कुकी जार में है। और उसने चढ़ने क...
# 545  हम्म छोटा लड़का स्टूल पर है जो ढो रहा है और वह...
# 546  ओह, आप चाहते हैं कि मैं आपको बता दूं। माँ और उ...
# 547  अगर उसकी माँ वहाँ नहीं घूमी और उसे पकड़ नहीं ल...
#
# [548 rows x 8 columns]

# %%
text = data['m2m_100_1.2B'].tolist()
clas = data['Labels'].tolist()

data = pd.DataFrame({'text': text, 'target': clas})

# %%
data
# Out:
#                                                   text  target
# 0    दृश्य रसोईघर में है माँ डिश धो रही है और पानी ...       0
# 1    मैं देखता हूं कि सिंहासन चल रहा है मैं देखता ह...       0
# 2    एक लड़का और एक लड़की अपनी मां के साथ रसोई में ...       0
# 3    ठीक है यह गर्मियों का समय था और माँ और बच्चे र...       0
# 4    तब तक इंतज़ार करें जब तक मैं अपने चश्मा पहनता ...       0
# ..                                                 ...     ...
# 543  छोटा बच्चा अपने कुर्सी से गिर रहा है माँ के पा...       1
# 544  एमएम यह एक कुकी जार में है और वह चढ़ने की कोशि...       1
# 545  हाँ छोटा लड़का कुर्सी पर है जो टिपिंग कर रहा ह...       1
# 546  आप चाहते हैं कि मैं आपको बताऊं मां और उसके दो ...       1
# 547  ओह उस बच्चे को उस मल से अच्छी तरह से फेंक दिया...       1
#
# [548 rows x 2 columns]

# %%
# # tokenization
# from indicnlp.tokenize import indic_tokenize
# def tokenization(indic_string):
#     tokens = []
#     for t in indic_tokenize.trivial_tokenize(indic_string):
#         tokens.append(t)
#     return tokens
# data['text'] = data['text'].apply(lambda x: tokenization(x))

# %%
# punctuations = ['nn','n','–', '।','/', '`', '+', '\\', '"', '?', '▁(', '$', '@', '[', '_', "\'", '!', ',', ':', '^', '|', ']', '=', '%', '&', '.', ')', '(', "#", '*', '', ';', '-', '}','|','"']

# stopwords_ni = ['तुम','मेरी','मुझे','क्योंकि','हम','प्रति','अबकी','आगे','माननीय','शहर','बताएं','कौनसी','क्लिक','किसकी','बड़े','मैं','and','रही','आज','लें','आपके','मिलकर','सब','मेरे','जी','श्री','वैसा','आपका','अंदर', 'अत', 'अपना', 
#                 'अपनी', 'अपने', 'अभी', 'आदि', 'आप', 'इत्यादि', 'इन', 'इनका', 'इन्हीं', 'इन्हें', 'इन्हों', 'इस', 'इसका', 'इसकी', 'इसके', 'इसमें', 'इसी', 'इसे', 'उन', 'उनका', 'उनकी', 'उनके', 'उनको', 'उन्हीं', 'उन्हें', 'उन्हों', 'उस', 
#                 'उसके', 'उसी', 'उसे', 'एक', 'एवं', 'एस', 'ऐसे', 'और', 'कई', 'कर','करता', 'करते', 'करना', 'करने', 'करें', 'कहते', 'कहा', 'का', 'काफ़ी', 'कि', 'कितना', 'किन्हें', 'किन्हों', 'किया', 'किर', 'किस', 'किसी', 'किसे', 
#                 'की', 'कुछ', 'कुल', 'के', 'को', 'कोई', 'कौन', 'कौनसा', 'गया', 'घर', 'जब', 'जहाँ', 'जा', 'जितना', 'जिन', 'जिन्हें', 'जिन्हों', 'जिस', 'जिसे', 'जीधर', 'जैसा', 'जैसे', 'जो', 'तक', 'तब', 'तरह', 'तिन', 'तिन्हें', 'तिन्हों',
#                 'तिस', 'तिसे', 'तो', 'था', 'थी', 'थे', 'दबारा', 'दिया', 'दुसरा', 'दूसरे', 'दो', 'द्वारा', 'न', 'नहीं', 'ना', 'निहायत', 'नीचे', 'ने', 'पर', 'पर', 'पहले', 'पूरा', 'पे', 'फिर', 'बनी', 'बही', 'बहुत', 'बाद', 'बाला', 'बिलकुल', 'भी',
#                 'भीतर', 'मगर', 'मानो', 'मे', 'में', 'यदि', 'यह', 'यहाँ', 'यही', 'या', 'यिह', 'ये', 'रखें', 'रहा', 'रहे', 'ऱ्वासा', 'लिए', 'लिये', 'लेकिन', 'व', 'वर्ग', 'वह', 'वह', 'वहाँ', 'वहीं', 'वाले', 'वुह', 'वे', 'वग़ैरह', 'संग', 'सकता', 'सकते',
#                 'सबसे', 'सभी', 'साथ', 'साबुत', 'साभ', 'सारा', 'से', 'सो', 'ही', 'हुआ', 'हुई', 'हुए', 'है', 'हैं', 'हो', 'होता', 'होती', 'होते', 'होना', 'होने', 'अपनि', 'जेसे', 'होति', 'सभि', 'तिंहों', 'इंहों', 'दवारा', 'इसि', 'किंहें', 'थि', 'उंहों', 'ओर', 
#                 'जिंहें', 'वहिं', 'अभि', 'बनि', 'हि', 'उंहिं', 'उंहें', 'हें', 'वगेरह', 'एसे', 'रवासा', 'कोन', 'निचे', 'काफि', 'उसि', 'पुरा', 'भितर', 
#                 'हे', 'बहि', 'वहां', 'कोइ', 'यहां', 'जिंहों', 'तिंहें', 'किसि', 'कइ', 'यहि', 'इंहिं', 'जिधर', 'इंहें', 'अदि', 'इतयादि', 'हुइ', 'कोनसा', 'इसकि', 'दुसरे', 'जहां', 'अप', 'किंहों', 'उनकि', 'भि', 'वरग', 'हुअ', 'जेसा', 'नहिं']
# to_be_removed =   punctuations
# # {'पर': 6, 'गर': 4, 'उन': 0, 'एम': 3, 'भन': 7, 'एक': 2, 'सक': 8, 'उव': 1, 'हर': 9, 'छन': 5}

# for i in range(len(data)):
#     data['text'][i]=[ele for ele in data['text'][i] if ele not in (to_be_removed)]
# # count_length()
# data.tail(2)

# %%
data.head(2)
# Out:
#                                                 text  target
# 0  दृश्य रसोईघर में है माँ डिश धो रही है और पानी ...       0
# 1  मैं देखता हूं कि सिंहासन चल रहा है मैं देखता ह...       0

# %%
# len(stopwords_ni)

# %%
# for i in range(len(data)):
#     data['text'][i] = [s.replace("\n", "") for s in data['text'][i]]

# %%
data
# Out:
#                                                   text  target
# 0    दृश्य रसोईघर में है माँ डिश धो रही है और पानी ...       0
# 1    मैं देखता हूं कि सिंहासन चल रहा है मैं देखता ह...       0
# 2    एक लड़का और एक लड़की अपनी मां के साथ रसोई में ...       0
# 3    ठीक है यह गर्मियों का समय था और माँ और बच्चे र...       0
# 4    तब तक इंतज़ार करें जब तक मैं अपने चश्मा पहनता ...       0
# ..                                                 ...     ...
# 543  छोटा बच्चा अपने कुर्सी से गिर रहा है माँ के पा...       1
# 544  एमएम यह एक कुकी जार में है और वह चढ़ने की कोशि...       1
# 545  हाँ छोटा लड़का कुर्सी पर है जो टिपिंग कर रहा ह...       1
# 546  आप चाहते हैं कि मैं आपको बताऊं मां और उसके दो ...       1
# 547  ओह उस बच्चे को उस मल से अच्छी तरह से फेंक दिया...       1
#
# [548 rows x 2 columns]

# %%
# # #Remove comma as a seperators
# for i in range(len(data)):
#     data['text'][i] = ' '.join(data['text'][i])
# data.tail(2)

# %%
train_df, test_df = train_test_split(data, test_size=0.10, random_state=42, shuffle=True)

# %%
len(train_df)
# Out:
# 493

# %%
len(test_df)
# Out:
# 55

# %%
label_names = ["target"]
y_train = train_df[label_names].values
train_df['doc_len'] = train_df['text'].apply(lambda words: len(words.split(" ")))
max_seq_len = np.round(train_df['doc_len'].mean() + train_df['doc_len'].std()).astype(int)

sns.distplot(train_df['doc_len'], hist=True, kde=True, color='b', label='doc len')
plt.axvline(x=max_seq_len, color='k', linestyle='--', label='max len')
plt.title('comment length'); plt.legend()
plt.show()
# Out:
# <ipython-input-23-89a3e2d80d32>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['doc_len'], hist=True, kde=True, color='b', label='doc len')

# %%
from sklearn.utils import shuffle
from keras.utils import pad_sequences


raw_docs_train = train_df['text'].tolist()
raw_docs_test = test_df['text'].tolist() 
num_classes = len(label_names)

print("pre-processing train data...")

processed_docs_train = []
for doc in tqdm(raw_docs_train):
    tokens = word_tokenize(doc)
    filtered = [word for word in tokens if word not in stop_words]
    processed_docs_train.append(" ".join(filtered))
#end for

processed_docs_test = []
for doc in tqdm(raw_docs_test):
    tokens = word_tokenize(doc)
    filtered = [word for word in tokens if word not in stop_words]
    processed_docs_test.append(" ".join(filtered))
#end for

print("tokenizing input data...")
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, lower=True, char_level=False)
tokenizer.fit_on_texts(processed_docs_train + processed_docs_test)  #leaky
word_seq_train = tokenizer.texts_to_sequences(processed_docs_train)
word_seq_test = tokenizer.texts_to_sequences(processed_docs_test)
word_index = tokenizer.word_index
print("dictionary size: ", len(word_index))

#pad sequences
word_seq_train = pad_sequences(word_seq_train, maxlen=max_seq_len)
word_seq_test = pad_sequences(word_seq_test, maxlen=max_seq_len)
# Out:
# pre-processing train data...
# 100%|██████████| 493/493 [00:00<00:00, 1987.06it/s]
# 100%|██████████| 55/55 [00:00<00:00, 1900.64it/s]
# tokenizing input data...
# dictionary size:  1943

# %%
len(word_seq_train)
# Out:
# 493

# %%
len(word_seq_test)
# Out:
# 55

# %%
max_seq_len
# Out:
# 147

# %%
# f = fasttext.load_model('/content/gdrive/MyDrive/pretrained_model/cc.hi.300.bin')


print('loading word embeddings...')

embeddings_index = {}
f = codecs.open('/content/gdrive/MyDrive/pretrained_model/cc.hi.300.vec', encoding='utf-8')

for line in tqdm(f):
    values = line.rstrip().rsplit(' ')
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('found %s word vectors' % len(embeddings_index))
# Out:
# loading word embeddings...
# 1876654it [03:26, 9095.37it/s]
# found 1876654 word vectors

# %%
#training params
batch_size = 128
num_epochs = 20

#model parameters
num_filters = 32 
embed_dim = 300 
weight_decay = 0.97

# %%
#embedding matrix

print('preparing embedding matrix...')

words_not_found = []
nb_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((nb_words, embed_dim))

for word, i in word_index.items():
    if i >= nb_words:
        continue
    embedding_vector = embeddings_index.get(word)
    if (embedding_vector is not None) and len(embedding_vector) > 0:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
    else:
        words_not_found.append(word)
print('number of null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# preparing embedding matrix...
# number of null word embeddings: 77

# %%
print("sample words not found: ", np.random.choice(words_not_found, 10))
# Out:
# sample words not found:  ['suk' 'howabout' 'hmhunh' 'hafta' 'अल्टोफ' 'गीगलिंग' 'sortof' 'हैह'
#  'स्पिगॉट' 'theyre']

# %%
embedding_matrix.shape
# Out:
# (1944, 300)

# %% [markdown]
# ## Bi-LSTM

# %%
model = Sequential()
# model.add(Embedding(nb_words,embed_dim,input_length=max_seq_len, weights=[embedding_matrix],trainable=False))
model.add(Embedding(nb_words,embed_dim,input_length=max_seq_len))
model.add(Bidirectional(LSTM(32 , activation='tanh' ,return_sequences=True ,  input_shape = (140 , 300) ,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))
model.add(Dropout(0.4))
model.add(Bidirectional(LSTM(16 , activation = 'tanh', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)  )))
model.add(Dropout(0.4))

model.add(Dense(128 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) ))
model.add(Dropout(0.3))
model.add(Dense(64 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid' ))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 147, 300)          583200
#
#  bidirectional_2 (Bidirectio  (None, 147, 64)          85248
#  nal)
#
#  dropout_4 (Dropout)         (None, 147, 64)           0
#
#  bidirectional_3 (Bidirectio  (None, 32)               10368
#  nal)
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 128)               4224
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 691,361
# Trainable params: 691,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

from keras.optimizers import SGD,Adam



# opt = Adam(clipvalue=0.5,learning_rate=0.0001)
opt = Adam()
model.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
word_seq_train
# Out:
# array([[  0,   0,   0, ...,   1,  46,  18],
#        [  0,   0,   0, ...,  13,   1, 199],
#        [  0,   0,   0, ...,  30, 112,  12],
#        ...,
#        [  0,   0,   0, ...,  20,  58,  40],
#        [  0,   0,   0, ...,  18, 550,   1],
#        [  1,   2,   6, ...,  18,  43,  73]], dtype=int32)

# %%
word_seq_train.shape
# Out:
# (493, 147)

# %%
y_train.shape
# Out:
# (493, 1)

# %%
# from imblearn.over_sampling import SMOTE, ADASYN
# X_train, Y_train = SMOTE().fit_resample(word_seq_train, y_train)

# %%
# X_train.shape
# y_train.shape

# %%
# es_callback = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(word_seq_train, y_train , batch_size=256,
          epochs=25, validation_split=0.10, shuffle=False)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 14s 3s/step - loss: 0.8199 - accuracy: 0.4673 - val_loss: 0.8164 - val_accuracy: 0.6000
# Epoch 2/25
# 2/2 [==============================] - 3s 1s/step - loss: 0.8154 - accuracy: 0.5418 - val_loss: 0.8102 - val_accuracy: 0.6000
# Epoch 3/25
# 2/2 [==============================] - 2s 794ms/step - loss: 0.8108 - accuracy: 0.5508 - val_loss: 0.8039 - val_accuracy: 0.6000
# Epoch 4/25
# 2/2 [==============================] - 2s 808ms/step - loss: 0.8067 - accuracy: 0.5485 - val_loss: 0.7977 - val_accuracy: 0.6000
# Epoch 5/25
# 2/2 [==============================] - 2s 785ms/step - loss: 0.8023 - accuracy: 0.5508 - val_loss: 0.7913 - val_accuracy: 0.6000
# Epoch 6/25
# 2/2 [==============================] - 2s 731ms/step - loss: 0.7966 - accuracy: 0.5508 - val_loss: 0.7847 - val_accuracy: 0.6000
# Epoch 7/25
# 2/2 [==============================] - 2s 791ms/step - loss: 0.7934 - accuracy: 0.5508 - val_loss: 0.7782 - val_accuracy: 0.6000
# Epoch 8/25
# 2/2 [==============================] - 2s 774ms/step - loss: 0.7866 - accuracy: 0.5508 - val_loss: 0.7716 - val_accuracy: 0.6000
# Epoch 9/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.7783 - accuracy: 0.5508 - val_loss: 0.7638 - val_accuracy: 0.6000
# Epoch 10/25
# 2/2 [==============================] - 2s 837ms/step - loss: 0.7704 - accuracy: 0.5508 - val_loss: 0.7542 - val_accuracy: 0.6000
# Epoch 11/25
# 2/2 [==============================] - 2s 728ms/step - loss: 0.7592 - accuracy: 0.5508 - val_loss: 0.7422 - val_accuracy: 0.6000
# Epoch 12/25
# 2/2 [==============================] - 2s 814ms/step - loss: 0.7419 - accuracy: 0.5553 - val_loss: 0.7267 - val_accuracy: 0.6000
# Epoch 13/25
# 2/2 [==============================] - 2s 781ms/step - loss: 0.7119 - accuracy: 0.5643 - val_loss: 0.7042 - val_accuracy: 0.6200
# Epoch 14/25
# 2/2 [==============================] - 2s 798ms/step - loss: 0.6760 - accuracy: 0.6456 - val_loss: 0.6729 - val_accuracy: 0.7000
# Epoch 15/25
# 2/2 [==============================] - 2s 737ms/step - loss: 0.6264 - accuracy: 0.7156 - val_loss: 0.6505 - val_accuracy: 0.7000
# Epoch 16/25
# 2/2 [==============================] - 2s 781ms/step - loss: 0.5707 - accuracy: 0.8104 - val_loss: 0.6232 - val_accuracy: 0.7200
# Epoch 17/25
# 2/2 [==============================] - 3s 1s/step - loss: 0.5147 - accuracy: 0.8804 - val_loss: 0.5937 - val_accuracy: 0.7600
# Epoch 18/25
# 2/2 [==============================] - 2s 735ms/step - loss: 0.4507 - accuracy: 0.9210 - val_loss: 0.6466 - val_accuracy: 0.7400
# Epoch 19/25
# 2/2 [==============================] - 2s 801ms/step - loss: 0.4047 - accuracy: 0.9255 - val_loss: 0.5749 - val_accuracy: 0.7600
# Epoch 20/25
# 2/2 [==============================] - 2s 727ms/step - loss: 0.3389 - accuracy: 0.9436 - val_loss: 0.7505 - val_accuracy: 0.6800
# Epoch 21/25
# 2/2 [==============================] - 2s 788ms/step - loss: 0.2931 - accuracy: 0.9639 - val_loss: 0.8928 - val_accuracy: 0.6800
# Epoch 22/25
# 2/2 [==============================] - 2s 793ms/step - loss: 0.2527 - accuracy: 0.9684 - val_loss: 0.8104 - val_accuracy: 0.7600
# Epoch 23/25
# 2/2 [==============================] - 2s 783ms/step - loss: 0.2234 - accuracy: 0.9752 - val_loss: 0.8765 - val_accuracy: 0.7600
# Epoch 24/25
# 2/2 [==============================] - 2s 1s/step - loss: 0.1744 - accuracy: 0.9797 - val_loss: 1.0522 - val_accuracy: 0.7400
# Epoch 25/25
# 2/2 [==============================] - 2s 784ms/step - loss: 0.1650 - accuracy: 0.9819 - val_loss: 1.2910 - val_accuracy: 0.7200

# %%
# #generate plots
# plt.figure()
# plt.plot(history.history['loss'], lw=2.0, color='b', label='train')
# plt.plot(history.history['val_loss'], lw=2.0, color='r', label='val')
# plt.title('LSTM sentiment')
# plt.xlabel('Epochs')
# plt.ylabel('Cross-Entropy Loss')
# plt.legend(loc='upper right')
# plt.show()

# %%
# plt.figure()
# plt.plot(history.history['accuracy'], lw=2.0, color='b', label='train')
# plt.plot(history.history['val_accuracy'], lw=2.0, color='r', label='val')
# plt.title('LSTM sentiment')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend(loc='upper left')
# plt.show()

# %%
predictions = model.predict(word_seq_test)
# predictions= predictions.ravel()

# sample=pd.read_csv('test_dat.csv')
test_df['pred']= (predictions>0.5).astype(int)
test_df[['pred', "target"]]
# Out:
# 2/2 [==============================] - 1s 55ms/step
#      pred  target
# 247     1       1
# 78      0       0
# 245     1       1
# 353     1       1
# 477     1       1
# 541     1       1
# 335     1       1
# 319     1       1
# 250     1       1
# 82      0       0
# 432     1       1
# 6       1       0
# 287     1       1
# 101     1       0
# 526     1       1
# 220     1       0
# 393     1       1
# 502     0       1
# 318     1       1
# 104     1       0
# 425     0       1
# 375     1       1
# 352     0       1
# 307     1       1
# 76      0       0
# 268     1       1
# 2       1       0
# 55      1       0
# 77      0       0
# 10      0       0
# 73      0       0
# 543     1       1
# 192     1       0
# 382     1       1
# 476     1       1
# 90      0       0
# 362     1       1
# 148     0       0
# 462     1       1
# 469     1       1
# 210     0       0
# 278     1       1
# 165     1       0
# 172     0       0
# 184     0       0
# 515     1       1
# 368     0       1
# 72      1       0
# 84      0       0
# 434     1       1
# 534     1       1
# 519     1       1
# 30      0       0
# 167     1       0
# 86      0       0

# %%
predictions.shape
# Out:
# (55, 1)

# %%
word_seq_test.shape
# Out:
# (55, 147)

# %%
test_df[["target"]].shape
# Out:
# (55, 1)

# %%
predictions.shape
# Out:
# (55, 1)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from imblearn.metrics import macro_averaged_mean_absolute_error

print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
print(confusion_matrix(test_df.target, test_df.pred))
# Out:
# Accuracy ->  0.7454545454545455
# Recall ->  0.7271505376344086
# Precision ->  0.7537537537537538
# F1 score ->  0.7303921568627451
# Macro MAE ->  0.2728494623655914
# [[14 10]
#  [ 4 27]]

# %%
# from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
# from imblearn.metrics import macro_averaged_mean_absolute_error

# print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
# print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
# print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
# print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# # print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
# print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
# print(confusion_matrix(test_df.target, test_df.pred))

# %% [markdown]
# ## LSTM

# %%
nb_words
# Out:
# 1848

# %%
embed_dim
# Out:
# 300

# %%
max_seq_len
# Out:
# 64

# %%
word_seq_train.shape
# Out:
# (492, 64)

# %%
model = Sequential()
model.add(Embedding(nb_words,embed_dim,input_length=max_seq_len))
model.add((LSTM(16 , activation='tanh' ,return_sequences=True ,  input_shape = (140 , 300) ,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))
model.add(Dropout(0.4))
model.add((LSTM(8 , activation = 'tanh', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))
model.add(Dropout(0.4))

model.add(Dense(128 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) ))
model.add(Dropout(0.2))
model.add(Dense(64 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model.add(Dense(1, activation='sigmoid' ))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 147, 300)          583200
#
#  lstm_14 (LSTM)              (None, 147, 16)           20288
#
#  dropout_23 (Dropout)        (None, 147, 16)           0
#
#  lstm_15 (LSTM)              (None, 8)                 800
#
#  dropout_24 (Dropout)        (None, 8)                 0
#
#  dense_21 (Dense)            (None, 128)               1152
#
#  dropout_25 (Dropout)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 64)                8256
#
#  dense_23 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 613,761
# Trainable params: 613,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

from keras.optimizers import SGD,Adam



# opt = Adam(clipvalue=0.5,learning_rate=0.0001)
opt = Adam()
model.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# es_callback = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(word_seq_train, y_train , batch_size=256,
          epochs=25, validation_split=0.10, shuffle=False)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 7s 2s/step - loss: 0.7364 - accuracy: 0.5530 - val_loss: 0.7338 - val_accuracy: 0.6000
# Epoch 2/25
# 2/2 [==============================] - 1s 519ms/step - loss: 0.7339 - accuracy: 0.5508 - val_loss: 0.7304 - val_accuracy: 0.6000
# Epoch 3/25
# 2/2 [==============================] - 1s 369ms/step - loss: 0.7308 - accuracy: 0.5508 - val_loss: 0.7269 - val_accuracy: 0.6000
# Epoch 4/25
# 2/2 [==============================] - 1s 361ms/step - loss: 0.7277 - accuracy: 0.5508 - val_loss: 0.7233 - val_accuracy: 0.6000
# Epoch 5/25
# 2/2 [==============================] - 1s 356ms/step - loss: 0.7244 - accuracy: 0.5508 - val_loss: 0.7195 - val_accuracy: 0.6000
# Epoch 6/25
# 2/2 [==============================] - 1s 324ms/step - loss: 0.7203 - accuracy: 0.5508 - val_loss: 0.7157 - val_accuracy: 0.6000
# Epoch 7/25
# 2/2 [==============================] - 1s 317ms/step - loss: 0.7148 - accuracy: 0.5508 - val_loss: 0.7117 - val_accuracy: 0.6000
# Epoch 8/25
# 2/2 [==============================] - 1s 330ms/step - loss: 0.7087 - accuracy: 0.5508 - val_loss: 0.7073 - val_accuracy: 0.6000
# Epoch 9/25
# 2/2 [==============================] - 1s 360ms/step - loss: 0.6991 - accuracy: 0.5508 - val_loss: 0.7022 - val_accuracy: 0.6000
# Epoch 10/25
# 2/2 [==============================] - 1s 347ms/step - loss: 0.6895 - accuracy: 0.5508 - val_loss: 0.6964 - val_accuracy: 0.6000
# Epoch 11/25
# 2/2 [==============================] - 1s 344ms/step - loss: 0.6773 - accuracy: 0.5508 - val_loss: 0.6893 - val_accuracy: 0.6000
# Epoch 12/25
# 2/2 [==============================] - 1s 342ms/step - loss: 0.6622 - accuracy: 0.5530 - val_loss: 0.6801 - val_accuracy: 0.6000
# Epoch 13/25
# 2/2 [==============================] - 1s 357ms/step - loss: 0.6395 - accuracy: 0.5801 - val_loss: 0.6686 - val_accuracy: 0.6200
# Epoch 14/25
# 2/2 [==============================] - 1s 318ms/step - loss: 0.6099 - accuracy: 0.6388 - val_loss: 0.6551 - val_accuracy: 0.6000
# Epoch 15/25
# 2/2 [==============================] - 1s 353ms/step - loss: 0.5842 - accuracy: 0.6772 - val_loss: 0.6397 - val_accuracy: 0.6600
# Epoch 16/25
# 2/2 [==============================] - 1s 347ms/step - loss: 0.5471 - accuracy: 0.7404 - val_loss: 0.6221 - val_accuracy: 0.6600
# Epoch 17/25
# 2/2 [==============================] - 1s 335ms/step - loss: 0.5078 - accuracy: 0.8059 - val_loss: 0.6021 - val_accuracy: 0.6800
# Epoch 18/25
# 2/2 [==============================] - 1s 514ms/step - loss: 0.4641 - accuracy: 0.8600 - val_loss: 0.5855 - val_accuracy: 0.7000
# Epoch 19/25
# 2/2 [==============================] - 1s 555ms/step - loss: 0.4290 - accuracy: 0.9097 - val_loss: 0.5773 - val_accuracy: 0.7600
# Epoch 20/25
# 2/2 [==============================] - 1s 555ms/step - loss: 0.3909 - accuracy: 0.9278 - val_loss: 0.5779 - val_accuracy: 0.7400
# Epoch 21/25
# 2/2 [==============================] - 1s 329ms/step - loss: 0.3552 - accuracy: 0.9391 - val_loss: 0.5801 - val_accuracy: 0.7600
# Epoch 22/25
# 2/2 [==============================] - 1s 360ms/step - loss: 0.3247 - accuracy: 0.9639 - val_loss: 0.5832 - val_accuracy: 0.7600
# Epoch 23/25
# 2/2 [==============================] - 1s 353ms/step - loss: 0.2908 - accuracy: 0.9616 - val_loss: 0.5971 - val_accuracy: 0.7600
# Epoch 24/25
# 2/2 [==============================] - 1s 319ms/step - loss: 0.2460 - accuracy: 0.9752 - val_loss: 0.6150 - val_accuracy: 0.7800
# Epoch 25/25
# 2/2 [==============================] - 1s 300ms/step - loss: 0.2195 - accuracy: 0.9684 - val_loss: 0.6454 - val_accuracy: 0.7800

# %%
# #generate plots
# plt.figure()
# plt.plot(history.history['loss'], lw=2.0, color='b', label='train')
# plt.plot(history.history['val_loss'], lw=2.0, color='r', label='val')
# plt.title('LSTM sentiment')
# plt.xlabel('Epochs')
# plt.ylabel('Cross-Entropy Loss')
# plt.legend(loc='upper right')
# plt.show()

# %%
# plt.figure()
# plt.plot(history.history['accuracy'], lw=2.0, color='b', label='train')
# plt.plot(history.history['val_accuracy'], lw=2.0, color='r', label='val')
# plt.title('LSTM sentiment')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend(loc='upper left')
# plt.show()

# %%
word_seq_test.shape
# Out:
# (55, 147)

# %%
word_seq_test
# Out:
# array([[   0,    0,    0, ...,    1,   18,    1],
#        [   0,    0,    0, ...,    7,   22,    1],
#        [  69,  176,   79, ...,   79,   26,    2],
#        ...,
#        [   5,  259,    7, ...,    1,  119,    1],
#        [   0,    0,    0, ...,   80,   34, 1943],
#        [   0,    0,    0, ...,    6,   83,    1]], dtype=int32)

# %%
predictions = model.predict(word_seq_test)
# predictions= predictions.ravel()

# sample=pd.read_csv('test_dat.csv')
test_df['pred']= (predictions>0.5).astype(int)
test_df[['pred', "target"]]
# Out:
# 2/2 [==============================] - 1s 28ms/step
#      pred  target
# 247     1       1
# 78      0       0
# 245     1       1
# 353     1       1
# 477     1       1
# 541     1       1
# 335     1       1
# 319     1       1
# 250     0       1
# 82      0       0
# 432     1       1
# 6       1       0
# 287     1       1
# 101     0       0
# 526     0       1
# 220     1       0
# 393     1       1
# 502     0       1
# 318     1       1
# 104     1       0
# 425     0       1
# 375     1       1
# 352     0       1
# 307     1       1
# 76      0       0
# 268     1       1
# 2       0       0
# 55      1       0
# 77      0       0
# 10      0       0
# 73      0       0
# 543     0       1
# 192     0       0
# 382     1       1
# 476     1       1
# 90      0       0
# 362     1       1
# 148     0       0
# 462     1       1
# 469     1       1
# 210     0       0
# 278     1       1
# 165     1       0
# 172     0       0
# 184     1       0
# 515     1       1
# 368     0       1
# 72      1       0
# 84      0       0
# 434     0       1
# 534     1       1
# 519     1       1
# 30      0       0
# 167     0       0
# 86      0       0

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from imblearn.metrics import macro_averaged_mean_absolute_error

print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
print(confusion_matrix(test_df.target, test_df.pred))
# Out:
# Accuracy ->  0.7272727272727273
# Recall ->  0.7251344086021505
# Precision ->  0.7233333333333334
# F1 score ->  0.723987955838073
# Macro MAE ->  0.2748655913978495
# [[17  7]
#  [ 8 23]]

# %%
# from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
# from imblearn.metrics import macro_averaged_mean_absolute_error

# print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
# print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
# print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
# print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# # print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
# print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
# print(confusion_matrix(test_df.target, test_df.pred))

# %% [markdown]
# ## CNN+LSTM

# %%
model = Sequential()
model.add(Embedding(1848,300,input_length=max_seq_len))

# model.add((Conv1D(16,(3) , activation='tanh' ,return_sequences=True ,  input_shape = (140 , 300) ,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))


model.add(Conv1D(8,(3),activation = 'tanh',kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) ))

model.add(MaxPool1D(3))

# model.add(Bidirectional(LSTM(8,return_sequences=True,activation='tanh',kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)  )))
model.add(Dropout(0.2))
# model.add(BatchNormalization())
model.add(Bidirectional(LSTM(8,activation='tanh',kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))


model.add(Dense(128 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model.add(Dropout(0.4))
model.add(Dense(32 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model.add(Dense(1, activation='sigmoid' ))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 64, 300)           554400
#
#  conv1d_7 (Conv1D)           (None, 62, 8)             7208
#
#  max_pooling1d_6 (MaxPooling  (None, 20, 8)            0
#  1D)
#
#  dropout_12 (Dropout)        (None, 20, 8)             0
#
#  bidirectional_10 (Bidirecti  (None, 16)               1088
#  onal)
#
#  dense_15 (Dense)            (None, 128)               2176
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 32)                4128
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 569,033
# Trainable params: 569,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

from keras.optimizers import SGD,Adam



# opt = Adam(clipvalue=0.5,learning_rate=0.0001)
opt = Adam(learning_rate=0.0001)
model.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# es_callback = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(word_seq_train, y_train , batch_size=256,
          epochs=25, validation_split=0.10, shuffle=False)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 8s 2s/step - loss: 0.7147 - accuracy: 0.5566 - val_loss: 0.7139 - val_accuracy: 0.6000
# Epoch 2/25
# 2/2 [==============================] - 1s 219ms/step - loss: 0.7144 - accuracy: 0.5385 - val_loss: 0.7129 - val_accuracy: 0.6000
# Epoch 3/25
# 2/2 [==============================] - 0s 187ms/step - loss: 0.7131 - accuracy: 0.5498 - val_loss: 0.7119 - val_accuracy: 0.6000
# Epoch 4/25
# 2/2 [==============================] - 0s 169ms/step - loss: 0.7132 - accuracy: 0.5452 - val_loss: 0.7109 - val_accuracy: 0.6000
# Epoch 5/25
# 2/2 [==============================] - 0s 175ms/step - loss: 0.7132 - accuracy: 0.5452 - val_loss: 0.7100 - val_accuracy: 0.6000
# Epoch 6/25
# 2/2 [==============================] - 0s 180ms/step - loss: 0.7127 - accuracy: 0.5475 - val_loss: 0.7090 - val_accuracy: 0.6000
# Epoch 7/25
# 2/2 [==============================] - 0s 187ms/step - loss: 0.7119 - accuracy: 0.5475 - val_loss: 0.7081 - val_accuracy: 0.6000
# Epoch 8/25
# 2/2 [==============================] - 0s 197ms/step - loss: 0.7117 - accuracy: 0.5475 - val_loss: 0.7071 - val_accuracy: 0.6000
# Epoch 9/25
# 2/2 [==============================] - 0s 192ms/step - loss: 0.7107 - accuracy: 0.5475 - val_loss: 0.7062 - val_accuracy: 0.6000
# Epoch 10/25
# 2/2 [==============================] - 0s 200ms/step - loss: 0.7110 - accuracy: 0.5475 - val_loss: 0.7052 - val_accuracy: 0.6000
# Epoch 11/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.7097 - accuracy: 0.5475 - val_loss: 0.7042 - val_accuracy: 0.6000
# Epoch 12/25
# 2/2 [==============================] - 0s 173ms/step - loss: 0.7095 - accuracy: 0.5475 - val_loss: 0.7031 - val_accuracy: 0.6000
# Epoch 13/25
# 2/2 [==============================] - 0s 179ms/step - loss: 0.7095 - accuracy: 0.5475 - val_loss: 0.7021 - val_accuracy: 0.6000
# Epoch 14/25
# 2/2 [==============================] - 0s 200ms/step - loss: 0.7072 - accuracy: 0.5475 - val_loss: 0.7011 - val_accuracy: 0.6000
# Epoch 15/25
# 2/2 [==============================] - 0s 174ms/step - loss: 0.7088 - accuracy: 0.5475 - val_loss: 0.7001 - val_accuracy: 0.6000
# Epoch 16/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.7065 - accuracy: 0.5475 - val_loss: 0.6991 - val_accuracy: 0.6000
# Epoch 17/25
# 2/2 [==============================] - 0s 187ms/step - loss: 0.7067 - accuracy: 0.5475 - val_loss: 0.6981 - val_accuracy: 0.6000
# Epoch 18/25
# 2/2 [==============================] - 0s 174ms/step - loss: 0.7060 - accuracy: 0.5475 - val_loss: 0.6971 - val_accuracy: 0.6000
# Epoch 19/25
# 2/2 [==============================] - 0s 182ms/step - loss: 0.7045 - accuracy: 0.5475 - val_loss: 0.6961 - val_accuracy: 0.6000
# Epoch 20/25
# 2/2 [==============================] - 0s 193ms/step - loss: 0.7048 - accuracy: 0.5475 - val_loss: 0.6950 - val_accuracy: 0.6000
# Epoch 21/25
# 2/2 [==============================] - 0s 192ms/step - loss: 0.7049 - accuracy: 0.5475 - val_loss: 0.6940 - val_accuracy: 0.6000
# Epoch 22/25
# 2/2 [==============================] - 0s 198ms/step - loss: 0.7037 - accuracy: 0.5475 - val_loss: 0.6930 - val_accuracy: 0.6000
# Epoch 23/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.7031 - accuracy: 0.5475 - val_loss: 0.6920 - val_accuracy: 0.6000
# Epoch 24/25
# 2/2 [==============================] - 0s 206ms/step - loss: 0.7025 - accuracy: 0.5543 - val_loss: 0.6910 - val_accuracy: 0.6000
# Epoch 25/25
# 2/2 [==============================] - 0s 171ms/step - loss: 0.7020 - accuracy: 0.5498 - val_loss: 0.6900 - val_accuracy: 0.6000

# %%
#generate plots
plt.figure()
plt.plot(history.history['loss'], lw=2.0, color='b', label='train')
plt.plot(history.history['val_loss'], lw=2.0, color='r', label='val')
plt.title('LSTM sentiment')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure()
plt.plot(history.history['accuracy'], lw=2.0, color='b', label='train')
plt.plot(history.history['val_accuracy'], lw=2.0, color='r', label='val')
plt.title('LSTM sentiment')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
predictions = model.predict(word_seq_test)
# predictions= predictions.ravel()

# sample=pd.read_csv('test_dat.csv')
test_df['pred']= (predictions>0.5).astype(int)
test_df[['pred', "target"]]
# Out:
# 2/2 [==============================] - 1s 13ms/step
#      pred  target
# 176     1       0
# 77      1       0
# 361     1       1
# 90      1       0
# 368     1       1
# 210     1       0
# 177     1       0
# 250     1       1
# 518     1       1
# 199     1       0
# 6       1       0
# 354     1       1
# 424     1       1
# 261     1       1
# 247     1       1
# 316     1       1
# 501     1       1
# 55      1       0
# 470     1       1
# 499     1       1
# 72      1       0
# 440     1       1
# 540     1       1
# 225     1       0
# 312     1       1
# 2       1       0
# 388     1       1
# 185     1       0
# 10      1       0
# 163     1       0
# 70      1       0
# 286     1       1
# 79      1       0
# 395     1       1
# 396     1       1
# 469     1       1
# 211     1       0
# 433     1       1
# 514     1       1
# 277     1       1
# 158     1       0
# 431     1       1
# 76      1       0
# 297     1       1
# 367     1       1
# 403     1       1
# 83      1       0
# 137     1       0
# 426     1       1
# 542     1       1
# 30      1       0
# 477     1       1
# 398     1       1
# 325     1       1
# 192     1       0

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from imblearn.metrics import macro_averaged_mean_absolute_error

print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
print(confusion_matrix(test_df.target, test_df.pred))
# Out:
# Accuracy ->  0.5818181818181818
# Recall ->  0.5
# Precision ->  0.2909090909090909
# F1 score ->  0.367816091954023
# Macro MAE ->  0.5
# [[ 0 23]
#  [ 0 32]]
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
