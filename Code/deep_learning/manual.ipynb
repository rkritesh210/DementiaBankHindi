# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
#For Pre-Processing
from tqdm import tqdm
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import RegexpTokenizer 
from nltk.tokenize import word_tokenize
import os, re, csv, math, codecs


# For Training
import keras
from keras import optimizers
from keras import backend as K
from keras import regularizers

from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Model,Sequential

# For array, dataset, and visualizing
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
np.random.seed(0)

MAX_NB_WORDS = 100000
tokenizer = RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))
stop_words.update(['।','.', ',', '"', "'", ':', ';', '(', ')', '[', ']', '{', '}'])




from sklearn.model_selection import train_test_split , LeaveOneOut
import pandas as pd
import numpy as np
np.random.seed(5)
import os
import keras.regularizers as regular
from keras.layers import Input, Dense,Conv1D,LSTM,GRU, Dropout, Flatten, Concatenate, MaxPool1D, Embedding, TimeDistributed, Bidirectional,Add, BatchNormalization
from keras.models import Model,Sequential
from keras import regularizers
import keras
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from tensorflow.keras.layers import Conv2D
from sklearn.metrics import mean_absolute_error
from imblearn.metrics import macro_averaged_mean_absolute_error
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !pip install indic-nlp-library
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.91-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 KB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from indic-nlp-library) (1.4.4)
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-1.2.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 27.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from indic-nlp-library) (1.22.4)
# Collecting sphinx-argparse
#   Downloading sphinx_argparse-0.4.0-py3-none-any.whl (12 kB)
# Collecting morfessor
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->indic-nlp-library) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: sphinx>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from sphinx-argparse->indic-nlp-library) (3.5.4)
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->indic-nlp-library) (0.16)
# Collecting sphinxcontrib-jquery!=3.0.0,>=2.0.0
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 KB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.3)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (23.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.13)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.5)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.27.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (67.6.1)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.14.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.12.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.1)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.2)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.9/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.3->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.12)
# Installing collected packages: morfessor, sphinxcontrib-jquery, sphinx-argparse, sphinx-rtd-theme, indic-nlp-library
# Successfully installed indic-nlp-library-0.91 morfessor-2.0.6 sphinx-argparse-0.4.0 sphinx-rtd-theme-1.2.0 sphinxcontrib-jquery-4.1

# %%
from sklearn.model_selection import train_test_split
data = pd.read_csv('/content/gdrive/MyDrive/Hindi AD/new_Manual_dataset.csv')

# %%
data['manual_trans'] = data[['manual_trans']].apply(lambda x: x.str.strip()).replace('', np.nan)
data = data.dropna(subset=['manual_trans'])
data.reset_index(drop=True, inplace=True)

# %%
len(data)
# Out:
# 547

# %%
punctuation_signs = list("?:!.,;|।")
data['manual_trans'] = data['manual_trans']

for punct_sign in punctuation_signs:   
    data['manual_trans'] = data['manual_trans'].str.replace(punct_sign, '')
# Out:
# <ipython-input-7-3348dc4fae69>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['manual_trans'] = data['manual_trans']
# <ipython-input-7-3348dc4fae69>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['manual_trans'] = data['manual_trans'].str.replace(punct_sign, '')
# <ipython-input-7-3348dc4fae69>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['manual_trans'] = data['manual_trans'].str.replace(punct_sign, '')

# %%
data['manual_trans'] = data['manual_trans'].apply(lambda x: x.replace('\n', ' '))
data['manual_trans'] = data['manual_trans'].apply(lambda x: x.replace('\t', ' '))
data['manual_trans'] = data['manual_trans'].apply(lambda x: x.replace('।', ' '))
data['manual_trans'] = data['manual_trans'].str.replace("    ", " ")
data['manual_trans'] = data['manual_trans'].str.replace('"', '')
data['manual_trans'] = data['manual_trans'].str.replace("'s", "")
data['manual_trans'] = data['manual_trans'].str.replace("।", "")
# Out:
# <ipython-input-8-77cf9407957d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['manual_trans'] = data['manual_trans'].apply(lambda x: x.replace('\n', ' '))
# <ipython-input-8-77cf9407957d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['manual_trans'] = data['manual_trans'].apply(lambda x: x.replace('\t', ' '))
# <ipython-input-8-77cf9407957d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['manual_trans'] = data['manual_trans'].apply(lambda x: x.replace('।', ' '))
# <ipython-input-8-77cf9407957d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['manual_trans'] = data['manual_trans'].str.replace("    ", " ")
# <ipython-input-8-77cf9407957d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['manual_trans'] = data['manual_trans'].str.replace('"', '')
# <ipython-input-8-77cf9407957d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['manual_trans'] = data['manual_trans'].str.replace("'s", "")
# <ipython-input-8-77cf9407957d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['manual_trans'] = data['manual_trans'].str.replace("।", "")

# %%
data
# Out:
#                                                   text  \
# 0    the scene is in the kitchen.the mother is wipi...
# 1    oh i see the sink is running over . i see the ...
# 2    a boy and a girl are in the kitchen with their...
# 3    okay . it was summertime and mother and the ch...
# 4    wait until i put my glasses on . oh there's a ...
# ..                                                 ...
# 542  well the little kid's falling off his stool . ...
# 543  mhm . well this one is in the cookie jar . and...
# 544  hm  the little boy is on the stool which is ti...
# 545  oh you want me to tell you . the mother and he...
# 546  oh that kid's gonna get a good spill off of th...
#
#                                 google_translated_text  \
# 0    दृश्य रसोई में है। माँ व्यंजन पोंछ रही है और प...
# 1    ओह, मुझे लगता है कि सिंक खत्म हो रहा है। मुझे ...
# 2    एक लड़का और एक लड़की अपनी माँ के साथ रसोई में ...
# 3    ठीक है । यह गर्मियों में था और माँ और बच्चे रस...
# 4    तब तक रुको जब तक मैं अपना चश्मा नहीं डालता। ओह...
# ..                                                 ...
# 542  खैर छोटा बच्चा अपने स्टूल से गिर रहा है। और मा...
# 543  एमएचएम। खैर यह एक कुकी जार में है। और उसने चढ़...
# 544  एचएम छोटा लड़का स्टूल पर है जो टिपिंग कर रहा ह...
# 545  ओह, आप चाहते हैं कि मैं आपको बताऊं। माँ और उसक...
# 546  ओह, कि बच्चे को उस स्टूल से एक अच्छा फैल जाना ...
#
#                                            mbart50_m2m  \
# 0    दृश्य रसोई में है। मां बर्तन धो रही है और पानी...
# 1    ओह मैं देखता हूँ सिंक ऊपर चल रहा है। मैं देखता...
# 2    एक लड़का और एक लड़की मां के साथ रसोईघर में हैं...
# 3    ठीक है। यह गर्मी का समय था और माँ और बच्चे रसो...
# 4    जब तक मैं अपने चश्मा लगाएं तक प्रतीक्षा करें। ...
# ..                                                 ...
# 542  ठीक है, छोटा बच्चा अपनी कुर्सी से गिर रहा है। ...
# 543  mhm। यह एक कुकी के बर्तन में है। और वो चढ़ने क...
# 544  हां, छोटा लड़का स्टूल पर है जो झुक रहा है और व...
# 545  ओह तुम चाहते हो कि मैं तुम्हें बता दूँ। मां और...
# 546  ओह उस बच्चे को उस स्टूल से अच्छी तरह से बाहर न...
#
#                                           m2m_100_1.2B  \
# 0    दृश्य रसोईघर में है. माँ डिश धो रही है और पानी...
# 1    मैं देखता हूं कि सिंहासन चल रहा है। मैं देखता ...
# 2    एक लड़का और एक लड़की अपनी मां के साथ रसोई में ...
# 3    ठीक है। यह गर्मियों का समय था और माँ और बच्चे ...
# 4    तब तक इंतज़ार करें जब तक मैं अपने चश्मा पहनता ...
# ..                                                 ...
# 542  छोटा बच्चा अपने कुर्सी से गिर रहा है। माँ के प...
# 543  एमएम यह एक कुकी जार में है। और वह चढ़ने की कोश...
# 544  हाँ, छोटा लड़का कुर्सी पर है जो टिपिंग कर रहा ...
# 545  आप चाहते हैं कि मैं आपको बताऊं। मां और उसके दो...
# 546  ओह, उस बच्चे को उस मल से अच्छी तरह से फेंक दिय...
#
#                                                opus-mt    Result  Labels  \
# 0    यह दृश्‍य किचिन में है । एक लड़का एक घड़े से क...   Control       0
# 1    ओह मैं सिंक खत्म हो रहा है देखते हैं. मुझे लगत...   Control       0
# 2    एक लड़का और लड़की रसोई में अपनी माँ के साथ हैं...   Control       0
# 3    ठीक है. गर्मियों का मौसम था और माँ और बच्चे रस...   Control       0
# 4    मैं पर मेरे चश्मा डाल जब तक इंतजार करें. ओह, ए...   Control       0
# ..                                                 ...       ...     ...
# 542  छोटा बच्चा अपनी चौकी से गिर रहा है. और वह (बस्...  Dementia       1
# 543  mh. अच्छी तरह से इस आदमी कुकी जार में है. और व...  Dementia       1
# 544  छोटे लड़के को उस चौकी पर है जिस पर सरकना है और...  Dementia       1
# 545  ओह तुम मुझे तुम्हें बताने के लिए चाहते हैं. मा...  Dementia       1
# 546  ओह है कि बच्चे वहाँ के चारों ओर नहीं बारी है क...  Dementia       1
#
#                                           manual_trans
# 0    दृश्य रसोई की है माँ बर्तन पोंछ रही है और पानी...
# 1    ओह मैं देख रहा हूँ कि सिंक बह निकला हैमैं देख ...
# 2    एक लड़का और एक लड़की रसोई में अपनी माँ के साथ ...
# 3    गर्मी का मौसम था और माँ और बच्चे रसोई में काम ...
# 4    जब तक मैं अपना चश्मा नहीं लगाता तब तक प्रतीक्ष...
# ..                                                 ...
# 542  अच्छ छोटा बच्चा अपने मल से गिर रहा है और माँ स...
# 543  महम अच्छा यह कुकी जार में है और उसने चढ़ने की ...
# 544  हम्म छोटा लड़का स्टूल पर है जो ढो रहा है और वह...
# 545  ओह आप चाहते हैं कि मैं आपको बता दूं माँ और उसक...
# 546  अगर उसकी माँ वहाँ नहीं घूमी और उसे पकड़ नहीं ल...
#
# [547 rows x 8 columns]

# %%
text = data['manual_trans'].tolist()
clas = data['Labels'].tolist()

data = pd.DataFrame({'text': text, 'target': clas})

# %%
data
# Out:
#                                                   text  target
# 0    दृश्य रसोई की है माँ बर्तन पोंछ रही है और पानी...       0
# 1    ओह मैं देख रहा हूँ कि सिंक बह निकला हैमैं देख ...       0
# 2    एक लड़का और एक लड़की रसोई में अपनी माँ के साथ ...       0
# 3    गर्मी का मौसम था और माँ और बच्चे रसोई में काम ...       0
# 4    जब तक मैं अपना चश्मा नहीं लगाता तब तक प्रतीक्ष...       0
# ..                                                 ...     ...
# 542  अच्छ छोटा बच्चा अपने मल से गिर रहा है और माँ स...       1
# 543  महम अच्छा यह कुकी जार में है और उसने चढ़ने की ...       1
# 544  हम्म छोटा लड़का स्टूल पर है जो ढो रहा है और वह...       1
# 545  ओह आप चाहते हैं कि मैं आपको बता दूं माँ और उसक...       1
# 546  अगर उसकी माँ वहाँ नहीं घूमी और उसे पकड़ नहीं ल...       1
#
# [547 rows x 2 columns]

# %%
# tokenization
from indicnlp.tokenize import indic_tokenize
def tokenization(indic_string):
    tokens = []
    for t in indic_tokenize.trivial_tokenize(indic_string):
        tokens.append(t)
    return tokens
data['text'] = data['text'].apply(lambda x: tokenization(x))

# %%
punctuations = ['nn','n','–', '।','/', '`', '+', '\\', '"', '?', '▁(', '$', '@', '[', '_', "\'", '!', ',', ':', '^', '|', ']', '=', '%', '&', '.', ')', '(', "#", '*', '', ';', '-', '}','|','"']

stopwords_ni = ['तुम','मेरी','मुझे','क्योंकि','हम','प्रति','अबकी','आगे','माननीय','शहर','बताएं','कौनसी','क्लिक','किसकी','बड़े','मैं','and','रही','आज','लें','आपके','मिलकर','सब','मेरे','जी','श्री','वैसा','आपका','अंदर', 'अत', 'अपना', 
                'अपनी', 'अपने', 'अभी', 'आदि', 'आप', 'इत्यादि', 'इन', 'इनका', 'इन्हीं', 'इन्हें', 'इन्हों', 'इस', 'इसका', 'इसकी', 'इसके', 'इसमें', 'इसी', 'इसे', 'उन', 'उनका', 'उनकी', 'उनके', 'उनको', 'उन्हीं', 'उन्हें', 'उन्हों', 'उस', 
                'उसके', 'उसी', 'उसे', 'एक', 'एवं', 'एस', 'ऐसे', 'और', 'कई', 'कर','करता', 'करते', 'करना', 'करने', 'करें', 'कहते', 'कहा', 'का', 'काफ़ी', 'कि', 'कितना', 'किन्हें', 'किन्हों', 'किया', 'किर', 'किस', 'किसी', 'किसे', 
                'की', 'कुछ', 'कुल', 'के', 'को', 'कोई', 'कौन', 'कौनसा', 'गया', 'घर', 'जब', 'जहाँ', 'जा', 'जितना', 'जिन', 'जिन्हें', 'जिन्हों', 'जिस', 'जिसे', 'जीधर', 'जैसा', 'जैसे', 'जो', 'तक', 'तब', 'तरह', 'तिन', 'तिन्हें', 'तिन्हों',
                'तिस', 'तिसे', 'तो', 'था', 'थी', 'थे', 'दबारा', 'दिया', 'दुसरा', 'दूसरे', 'दो', 'द्वारा', 'न', 'नहीं', 'ना', 'निहायत', 'नीचे', 'ने', 'पर', 'पर', 'पहले', 'पूरा', 'पे', 'फिर', 'बनी', 'बही', 'बहुत', 'बाद', 'बाला', 'बिलकुल', 'भी',
                'भीतर', 'मगर', 'मानो', 'मे', 'में', 'यदि', 'यह', 'यहाँ', 'यही', 'या', 'यिह', 'ये', 'रखें', 'रहा', 'रहे', 'ऱ्वासा', 'लिए', 'लिये', 'लेकिन', 'व', 'वर्ग', 'वह', 'वह', 'वहाँ', 'वहीं', 'वाले', 'वुह', 'वे', 'वग़ैरह', 'संग', 'सकता', 'सकते',
                'सबसे', 'सभी', 'साथ', 'साबुत', 'साभ', 'सारा', 'से', 'सो', 'ही', 'हुआ', 'हुई', 'हुए', 'है', 'हैं', 'हो', 'होता', 'होती', 'होते', 'होना', 'होने', 'अपनि', 'जेसे', 'होति', 'सभि', 'तिंहों', 'इंहों', 'दवारा', 'इसि', 'किंहें', 'थि', 'उंहों', 'ओर', 
                'जिंहें', 'वहिं', 'अभि', 'बनि', 'हि', 'उंहिं', 'उंहें', 'हें', 'वगेरह', 'एसे', 'रवासा', 'कोन', 'निचे', 'काफि', 'उसि', 'पुरा', 'भितर', 
                'हे', 'बहि', 'वहां', 'कोइ', 'यहां', 'जिंहों', 'तिंहें', 'किसि', 'कइ', 'यहि', 'इंहिं', 'जिधर', 'इंहें', 'अदि', 'इतयादि', 'हुइ', 'कोनसा', 'इसकि', 'दुसरे', 'जहां', 'अप', 'किंहों', 'उनकि', 'भि', 'वरग', 'हुअ', 'जेसा', 'नहिं']
to_be_removed =  stopwords_ni + punctuations
# {'पर': 6, 'गर': 4, 'उन': 0, 'एम': 3, 'भन': 7, 'एक': 2, 'सक': 8, 'उव': 1, 'हर': 9, 'छन': 5}

for i in range(len(data)):
    data['text'][i]=[ele for ele in data['text'][i] if ele not in (to_be_removed)]
# count_length()
data.tail(2)
# Out:
# <ipython-input-13-7eb9071b78fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['text'][i]=[ele for ele in data['text'][i] if ele not in (to_be_removed)]
#                                                   text  target
# 545  [ओह, चाहते, आपको, बता, दूं, माँ, बच्चे, बच्चे,...       1
# 546  [अगर, उसकी, माँ, घूमी, पकड़, लिया, बच्चे, स्टू...       1

# %%
len(stopwords_ni)
# Out:
# 255

# %%
for i in range(len(data)):
    data['text'][i] = [s.replace("\n", "") for s in data['text'][i]]
# Out:
# <ipython-input-15-d517b1798ce8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['text'][i] = [s.replace("\n", "") for s in data['text'][i]]

# %%
data
# Out:
#                                                   text  target
# 0    [दृश्य, रसोई, माँ, बर्तन, पोंछ, पानी, फर्श, बह...       0
# 1    [ओह, देख, हूँ, सिंक, बह, निकला, हैमैं, देख, हू...       0
# 2    [लड़का, लड़की, रसोई, माँ, छोटा, लड़का, छोटी, ल...       0
# 3    [गर्मी, मौसम, माँ, बच्चे, रसोई, काम, खिड़की, ख...       0
# 4    [चश्मा, लगाता, प्रतीक्षा, ओह, लड़की, कुकी, पहु...       0
# ..                                                 ...     ...
# 542  [अच्छ, छोटा, बच्चा, मल, गिर, माँ, सिंक, ऊपर, प...       1
# 543  [महम, अच्छा, कुकी, जार, उसने, चढ़ने, कोशिश, अर...       1
# 544  [हम्म, छोटा, लड़का, स्टूल, ढो, बहन, कुकीज़, दे...       1
# 545  [ओह, चाहते, आपको, बता, दूं, माँ, बच्चे, बच्चे,...       1
# 546  [अगर, उसकी, माँ, घूमी, पकड़, लिया, बच्चे, स्टू...       1
#
# [547 rows x 2 columns]

# %%
# #Remove comma as a seperators
for i in range(len(data)):
    data['text'][i] = ' '.join(data['text'][i])
data.tail(2)
# Out:
# <ipython-input-17-8437b0cd79bf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['text'][i] = ' '.join(data['text'][i])
#                                                   text  target
# 545  ओह चाहते आपको बता दूं माँ बच्चे बच्चे कुकी जार...       1
# 546  अगर उसकी माँ घूमी पकड़ लिया बच्चे स्टूल अच्छी ...       1

# %%
train_df, test_df = train_test_split(data, test_size=0.10, random_state=42, shuffle=True)

# %%
len(train_df)
# Out:
# 492

# %%
len(test_df)
# Out:
# 55

# %%
label_names = ["target"]
y_train = train_df[label_names].values
train_df['doc_len'] = train_df['text'].apply(lambda words: len(words.split(" ")))
max_seq_len = np.round(train_df['doc_len'].mean() + train_df['doc_len'].std()).astype(int)

sns.distplot(train_df['doc_len'], hist=True, kde=True, color='b', label='doc len')
plt.axvline(x=max_seq_len, color='k', linestyle='--', label='max len')
plt.title('comment length'); plt.legend()
plt.show()
# Out:
# <ipython-input-21-89a3e2d80d32>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['doc_len'], hist=True, kde=True, color='b', label='doc len')

# %%
from sklearn.utils import shuffle
from keras.utils import pad_sequences


raw_docs_train = train_df['text'].tolist()
raw_docs_test = test_df['text'].tolist() 
num_classes = len(label_names)

print("pre-processing train data...")

processed_docs_train = []
for doc in tqdm(raw_docs_train):
    tokens = word_tokenize(doc)
    filtered = [word for word in tokens if word not in stop_words]
    processed_docs_train.append(" ".join(filtered))
#end for

processed_docs_test = []
for doc in tqdm(raw_docs_test):
    tokens = word_tokenize(doc)
    filtered = [word for word in tokens if word not in stop_words]
    processed_docs_test.append(" ".join(filtered))
#end for

print("tokenizing input data...")
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, lower=True, char_level=False)
tokenizer.fit_on_texts(processed_docs_train + processed_docs_test)  #leaky
word_seq_train = tokenizer.texts_to_sequences(processed_docs_train)
word_seq_test = tokenizer.texts_to_sequences(processed_docs_test)
word_index = tokenizer.word_index
print("dictionary size: ", len(word_index))

#pad sequences
word_seq_train = pad_sequences(word_seq_train, maxlen=max_seq_len)
word_seq_test = pad_sequences(word_seq_test, maxlen=max_seq_len)
# Out:
# pre-processing train data...
# 100%|██████████| 492/492 [00:00<00:00, 3591.74it/s]
# 100%|██████████| 55/55 [00:00<00:00, 2999.32it/s]
# tokenizing input data...
# dictionary size:  1847

# %%
len(word_seq_train)
# Out:
# 492

# %%
len(word_seq_test)
# Out:
# 55

# %%
max_seq_len
# Out:
# 64

# %%
# # f = fasttext.load_model('/content/gdrive/MyDrive/pretrained_model/cc.hi.300.bin')


# print('loading word embeddings...')

# embeddings_index = {}
# f = codecs.open('/content/gdrive/MyDrive/pretrained_model/cc.hi.300.vec', encoding='utf-8')

# for line in tqdm(f):
#     values = line.rstrip().rsplit(' ')
#     word = values[0]
#     coefs = np.asarray(values[1:], dtype='float32')
#     embeddings_index[word] = coefs
# f.close()

# print('found %s word vectors' % len(embeddings_index))

# %%
#training params
batch_size = 128
num_epochs = 20

#model parameters
num_filters = 32 
embed_dim = 300 
weight_decay = 0.97

# %%
# #embedding matrix

# print('preparing embedding matrix...')

# words_not_found = []
# nb_words = min(MAX_NB_WORDS, len(word_index)+1)
# embedding_matrix = np.zeros((nb_words, embed_dim))

# for word, i in word_index.items():
#     if i >= nb_words:
#         continue
#     embedding_vector = embeddings_index.get(word)
#     if (embedding_vector is not None) and len(embedding_vector) > 0:
#         # words not found in embedding index will be all-zeros.
#         embedding_matrix[i] = embedding_vector
#     else:
#         words_not_found.append(word)
# print('number of null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))

# %%
# print("sample words not found: ", np.random.choice(words_not_found, 10))

# %%
# embedding_matrix.shape

# %% [markdown]
# ## Bi-LSTM

# %%
model = Sequential()
# model.add(Embedding(nb_words,embed_dim,input_length=max_seq_len, weights=[embedding_matrix],trainable=False))
model.add(Embedding(1848,300,input_length=max_seq_len))
model.add(Bidirectional(LSTM(32 , activation='tanh' ,return_sequences=True ,  input_shape = (140 , 300) ,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(16 , activation = 'tanh', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)  )))
model.add(Dropout(0.3))

model.add(Dense(128 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) ))
model.add(Dropout(0.3))
model.add(Dense(64 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid' ))
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_16 (Embedding)    (None, 64, 300)           554400
#
#  bidirectional_28 (Bidirecti  (None, 64, 64)           85248
#  onal)
#
#  dropout_54 (Dropout)        (None, 64, 64)            0
#
#  bidirectional_29 (Bidirecti  (None, 32)               10368
#  onal)
#
#  dropout_55 (Dropout)        (None, 32)                0
#
#  dense_48 (Dense)            (None, 128)               4224
#
#  dropout_56 (Dropout)        (None, 128)               0
#
#  dense_49 (Dense)            (None, 64)                8256
#
#  dropout_57 (Dropout)        (None, 64)                0
#
#  dense_50 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 662,561
# Trainable params: 662,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

from keras.optimizers import SGD,Adam



# opt = Adam(clipvalue=0.5,learning_rate=0.0001)
opt = Adam()
model.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
word_seq_train
# Out:
# array([[115,  13,  37, ...,  24,  56, 132],
#        [  0,   0,   0, ..., 263,  18,  35],
#        [  0,   0,   0, ...,  46, 524,  10],
#        ...,
#        [  0,   0,   0, ..., 136, 769,  48],
#        [  0,   0,   0, ...,  38, 143,  38],
#        [ 68,  20,   8, ...,  59,  59, 132]], dtype=int32)

# %%
word_seq_train.shape
# Out:
# (492, 64)

# %%
y_train.shape
# Out:
# (492, 1)

# %%
from imblearn.over_sampling import SMOTE, ADASYN
X_train, Y_train = SMOTE().fit_resample(word_seq_train, y_train)

# %%
X_train.shape
# y_train.shape
# Out:
# (544, 64)

# %%
# es_callback = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(word_seq_train, y_train , batch_size=256,
          epochs=25, validation_split=0.10, shuffle=False)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 10s 2s/step - loss: 0.8203 - accuracy: 0.5090 - val_loss: 0.8140 - val_accuracy: 0.6000
# Epoch 2/25
# 2/2 [==============================] - 1s 408ms/step - loss: 0.8139 - accuracy: 0.5747 - val_loss: 0.8042 - val_accuracy: 0.6000
# Epoch 3/25
# 2/2 [==============================] - 1s 645ms/step - loss: 0.8060 - accuracy: 0.5611 - val_loss: 0.7927 - val_accuracy: 0.6000
# Epoch 4/25
# 2/2 [==============================] - 1s 747ms/step - loss: 0.7974 - accuracy: 0.5543 - val_loss: 0.7793 - val_accuracy: 0.6000
# Epoch 5/25
# 2/2 [==============================] - 1s 703ms/step - loss: 0.7844 - accuracy: 0.5475 - val_loss: 0.7635 - val_accuracy: 0.6200
# Epoch 6/25
# 2/2 [==============================] - 1s 394ms/step - loss: 0.7730 - accuracy: 0.5724 - val_loss: 0.7464 - val_accuracy: 0.6800
# Epoch 7/25
# 2/2 [==============================] - 1s 399ms/step - loss: 0.7558 - accuracy: 0.6109 - val_loss: 0.7285 - val_accuracy: 0.7000
# Epoch 8/25
# 2/2 [==============================] - 1s 383ms/step - loss: 0.7248 - accuracy: 0.6629 - val_loss: 0.7080 - val_accuracy: 0.7200
# Epoch 9/25
# 2/2 [==============================] - 1s 379ms/step - loss: 0.6915 - accuracy: 0.7217 - val_loss: 0.6816 - val_accuracy: 0.7200
# Epoch 10/25
# 2/2 [==============================] - 1s 370ms/step - loss: 0.6438 - accuracy: 0.7873 - val_loss: 0.6483 - val_accuracy: 0.7600
# Epoch 11/25
# 2/2 [==============================] - 1s 402ms/step - loss: 0.5756 - accuracy: 0.8597 - val_loss: 0.6110 - val_accuracy: 0.8000
# Epoch 12/25
# 2/2 [==============================] - 1s 374ms/step - loss: 0.5130 - accuracy: 0.8982 - val_loss: 0.5669 - val_accuracy: 0.8000
# Epoch 13/25
# 2/2 [==============================] - 1s 399ms/step - loss: 0.4457 - accuracy: 0.9140 - val_loss: 0.5494 - val_accuracy: 0.8200
# Epoch 14/25
# 2/2 [==============================] - 1s 378ms/step - loss: 0.3698 - accuracy: 0.9276 - val_loss: 0.5634 - val_accuracy: 0.8200
# Epoch 15/25
# 2/2 [==============================] - 1s 382ms/step - loss: 0.3267 - accuracy: 0.9389 - val_loss: 0.6006 - val_accuracy: 0.8200
# Epoch 16/25
# 2/2 [==============================] - 1s 389ms/step - loss: 0.2653 - accuracy: 0.9615 - val_loss: 0.6810 - val_accuracy: 0.8000
# Epoch 17/25
# 2/2 [==============================] - 1s 379ms/step - loss: 0.2167 - accuracy: 0.9706 - val_loss: 0.7353 - val_accuracy: 0.8000
# Epoch 18/25
# 2/2 [==============================] - 1s 411ms/step - loss: 0.1881 - accuracy: 0.9796 - val_loss: 0.9086 - val_accuracy: 0.7600
# Epoch 19/25
# 2/2 [==============================] - 1s 683ms/step - loss: 0.1603 - accuracy: 0.9842 - val_loss: 1.1011 - val_accuracy: 0.7600
# Epoch 20/25
# 2/2 [==============================] - 1s 730ms/step - loss: 0.1379 - accuracy: 0.9932 - val_loss: 1.1096 - val_accuracy: 0.7600
# Epoch 21/25
# 2/2 [==============================] - 1s 662ms/step - loss: 0.1288 - accuracy: 0.9910 - val_loss: 1.1398 - val_accuracy: 0.7800
# Epoch 22/25
# 2/2 [==============================] - 1s 381ms/step - loss: 0.1129 - accuracy: 0.9955 - val_loss: 1.3879 - val_accuracy: 0.7600
# Epoch 23/25
# 2/2 [==============================] - 1s 387ms/step - loss: 0.1440 - accuracy: 0.9842 - val_loss: 1.3458 - val_accuracy: 0.7400
# Epoch 24/25
# 2/2 [==============================] - 1s 370ms/step - loss: 0.1193 - accuracy: 0.9932 - val_loss: 1.6600 - val_accuracy: 0.6800
# Epoch 25/25
# 2/2 [==============================] - 1s 383ms/step - loss: 0.1072 - accuracy: 0.9932 - val_loss: 1.4572 - val_accuracy: 0.7200

# %%
#generate plots
plt.figure()
plt.plot(history.history['loss'], lw=2.0, color='b', label='train')
plt.plot(history.history['val_loss'], lw=2.0, color='r', label='val')
plt.title('LSTM sentiment')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure()
plt.plot(history.history['accuracy'], lw=2.0, color='b', label='train')
plt.plot(history.history['val_accuracy'], lw=2.0, color='r', label='val')
plt.title('LSTM sentiment')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
predictions = model.predict(word_seq_test)
# predictions= predictions.ravel()

# sample=pd.read_csv('test_dat.csv')
test_df['pred']= (predictions>0.5).astype(int)
test_df[['pred', "target"]]
# Out:
# 2/2 [==============================] - 1s 24ms/step
#      pred  target
# 176     0       0
# 77      0       0
# 361     1       1
# 90      0       0
# 368     1       1
# 210     0       0
# 177     1       0
# 250     0       1
# 518     1       1
# 199     0       0
# 6       0       0
# 354     1       1
# 424     0       1
# 261     1       1
# 247     1       1
# 316     1       1
# 501     1       1
# 55      0       0
# 470     1       1
# 499     1       1
# 72      0       0
# 440     1       1
# 540     1       1
# 225     0       0
# 312     0       1
# 2       0       0
# 388     1       1
# 185     1       0
# 10      1       0
# 163     0       0
# 70      0       0
# 286     1       1
# 79      0       0
# 395     1       1
# 396     1       1
# 469     1       1
# 211     0       0
# 433     1       1
# 514     1       1
# 277     1       1
# 158     0       0
# 431     1       1
# 76      0       0
# 297     1       1
# 367     1       1
# 403     0       1
# 83      0       0
# 137     0       0
# 426     1       1
# 542     1       1
# 30      0       0
# 477     1       1
# 398     1       1
# 325     1       1
# 192     0       0

# %%
predictions.shape
# Out:
# (55, 1)

# %%
word_seq_test.shape
# Out:
# (55, 64)

# %%
test_df[["target"]].shape
# Out:
# (55, 1)

# %%
predictions.shape
# Out:
# (55, 1)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from imblearn.metrics import macro_averaged_mean_absolute_error

print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
print(confusion_matrix(test_df.target, test_df.pred))
# Out:
# Accuracy ->  0.8727272727272727
# Recall ->  0.8722826086956521
# Precision ->  0.8682795698924731
# F1 score ->  0.8699763593380614
# Macro MAE ->  0.12771739130434784
# [[20  3]
#  [ 4 28]]

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from imblearn.metrics import macro_averaged_mean_absolute_error

print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
print(confusion_matrix(test_df.target, test_df.pred))
# Out:
# Accuracy ->  0.8545454545454545
# Recall ->  0.8505434782608696
# Precision ->  0.8505434782608696
# F1 score ->  0.8505434782608696
# Macro MAE ->  0.14945652173913043
# [[19  4]
#  [ 4 28]]

# %% [markdown]
# ## LSTM

# %%
nb_words
# Out:
# 1848

# %%
embed_dim
# Out:
# 300

# %%
max_seq_len
# Out:
# 64

# %%
word_seq_train.shape
# Out:
# (492, 64)

# %%
  model = Sequential()
  model.add(Embedding(1848,300,input_length=max_seq_len))
  model.add((LSTM(16 , activation='tanh' ,return_sequences=True ,  input_shape = (140 , 300) ,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))
  model.add(Dropout(0.4))

  model.add((LSTM(16 , activation = 'tanh',return_sequences=True, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)  )))
  model.add((LSTM(8 , activation = 'tanh',return_sequences=True, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))
  model.add((LSTM(4 , activation = 'tanh' , kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))
  model.add(Dropout(0.25))
  
  model.add(Dense(128 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) ))
  model.add(Dense(64 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
  model.add(Dense(1, activation='sigmoid' ))
  model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 64, 300)           554400
#
#  lstm_12 (LSTM)              (None, 64, 16)            20288
#
#  dropout_10 (Dropout)        (None, 64, 16)            0
#
#  lstm_13 (LSTM)              (None, 64, 16)            2112
#
#  lstm_14 (LSTM)              (None, 64, 8)             800
#
#  lstm_15 (LSTM)              (None, 4)                 208
#
#  dropout_11 (Dropout)        (None, 4)                 0
#
#  dense_12 (Dense)            (None, 128)               640
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dense_14 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 586,769
# Trainable params: 586,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

from keras.optimizers import SGD,Adam



# opt = Adam(clipvalue=0.5,learning_rate=0.0001)
opt = Adam()
model.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# es_callback = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(word_seq_train, y_train , batch_size=16,
          epochs=30, validation_split=0.10, shuffle=False)
# Out:
# Epoch 1/30
# 28/28 [==============================] - 11s 154ms/step - loss: 0.7214 - accuracy: 0.5588 - val_loss: 0.6752 - val_accuracy: 0.6800
# Epoch 2/30
# 28/28 [==============================] - 3s 110ms/step - loss: 0.6044 - accuracy: 0.7466 - val_loss: 0.5862 - val_accuracy: 0.7600
# Epoch 3/30
# 28/28 [==============================] - 3s 116ms/step - loss: 0.3815 - accuracy: 0.8665 - val_loss: 0.6062 - val_accuracy: 0.7400
# Epoch 4/30
# 28/28 [==============================] - 3s 94ms/step - loss: 0.2653 - accuracy: 0.9253 - val_loss: 0.8608 - val_accuracy: 0.6600
# Epoch 5/30
# 28/28 [==============================] - 3s 94ms/step - loss: 0.2091 - accuracy: 0.9457 - val_loss: 0.7888 - val_accuracy: 0.7400
# Epoch 6/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2534 - accuracy: 0.9208 - val_loss: 0.7797 - val_accuracy: 0.7400
# Epoch 7/30
# 28/28 [==============================] - 3s 113ms/step - loss: 0.2159 - accuracy: 0.9389 - val_loss: 0.8822 - val_accuracy: 0.7400
# Epoch 8/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.2962 - accuracy: 0.8937 - val_loss: 0.6401 - val_accuracy: 0.7600
# Epoch 9/30
# 28/28 [==============================] - 3s 99ms/step - loss: 0.1244 - accuracy: 0.9796 - val_loss: 1.1373 - val_accuracy: 0.7000
# Epoch 10/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0803 - accuracy: 0.9842 - val_loss: 0.9678 - val_accuracy: 0.7000
# Epoch 11/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0636 - accuracy: 0.9932 - val_loss: 1.4574 - val_accuracy: 0.6800
# Epoch 12/30
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0514 - accuracy: 0.9910 - val_loss: 1.4359 - val_accuracy: 0.6800
# Epoch 13/30
# 28/28 [==============================] - 3s 108ms/step - loss: 0.0419 - accuracy: 0.9955 - val_loss: 1.6289 - val_accuracy: 0.6600
# Epoch 14/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.0423 - accuracy: 0.9955 - val_loss: 1.8245 - val_accuracy: 0.6400
# Epoch 15/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 1.7397 - val_accuracy: 0.6800
# Epoch 16/30
# 28/28 [==============================] - 3s 101ms/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 1.7839 - val_accuracy: 0.7000
# Epoch 17/30
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0302 - accuracy: 0.9977 - val_loss: 1.8543 - val_accuracy: 0.7000
# Epoch 18/30
# 28/28 [==============================] - 3s 99ms/step - loss: 0.0285 - accuracy: 0.9977 - val_loss: 1.9853 - val_accuracy: 0.6800
# Epoch 19/30
# 28/28 [==============================] - 3s 99ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 2.0571 - val_accuracy: 0.6800
# Epoch 20/30
# 28/28 [==============================] - 3s 100ms/step - loss: 0.0285 - accuracy: 0.9955 - val_loss: 2.1307 - val_accuracy: 0.6800
# Epoch 21/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.0273 - accuracy: 0.9955 - val_loss: 2.1488 - val_accuracy: 0.7000
# Epoch 22/30
# 28/28 [==============================] - 3s 116ms/step - loss: 0.0269 - accuracy: 0.9977 - val_loss: 2.1529 - val_accuracy: 0.7000
# Epoch 23/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 2.1508 - val_accuracy: 0.7000
# Epoch 24/30
# 28/28 [==============================] - 3s 98ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 2.1954 - val_accuracy: 0.6800
# Epoch 25/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0245 - accuracy: 0.9977 - val_loss: 2.2312 - val_accuracy: 0.6800
# Epoch 26/30
# 28/28 [==============================] - 3s 118ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 2.2365 - val_accuracy: 0.7000
# Epoch 27/30
# 28/28 [==============================] - 3s 109ms/step - loss: 0.0250 - accuracy: 0.9977 - val_loss: 2.1605 - val_accuracy: 0.7000
# Epoch 28/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 2.2321 - val_accuracy: 0.7000
# Epoch 29/30
# 28/28 [==============================] - 3s 94ms/step - loss: 0.0240 - accuracy: 0.9977 - val_loss: 2.2978 - val_accuracy: 0.6800
# Epoch 30/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 2.2808 - val_accuracy: 0.6800

# %%
#generate plots
plt.figure()
plt.plot(history.history['loss'], lw=2.0, color='b', label='train')
plt.plot(history.history['val_loss'], lw=2.0, color='r', label='val')
plt.title('LSTM sentiment')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure()
plt.plot(history.history['accuracy'], lw=2.0, color='b', label='train')
plt.plot(history.history['val_accuracy'], lw=2.0, color='r', label='val')
plt.title('LSTM sentiment')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
predictions = model.predict(word_seq_test)
# predictions= predictions.ravel()

# sample=pd.read_csv('test_dat.csv')
test_df['pred']= (predictions>0.5).astype(int)
test_df[['pred', "target"]]
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4e21bd94c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 24ms/step
#      pred  target
# 176     0       0
# 77      0       0
# 361     1       1
# 90      0       0
# 368     1       1
# 210     0       0
# 177     0       0
# 250     0       1
# 518     1       1
# 199     0       0
# 6       0       0
# 354     1       1
# 424     0       1
# 261     1       1
# 247     1       1
# 316     1       1
# 501     0       1
# 55      0       0
# 470     1       1
# 499     1       1
# 72      0       0
# 440     1       1
# 540     0       1
# 225     0       0
# 312     1       1
# 2       0       0
# 388     0       1
# 185     1       0
# 10      0       0
# 163     0       0
# 70      0       0
# 286     1       1
# 79      0       0
# 395     1       1
# 396     1       1
# 469     1       1
# 211     0       0
# 433     1       1
# 514     0       1
# 277     1       1
# 158     0       0
# 431     1       1
# 76      0       0
# 297     1       1
# 367     1       1
# 403     0       1
# 83      0       0
# 137     0       0
# 426     1       1
# 542     1       1
# 30      0       0
# 477     0       1
# 398     1       1
# 325     1       1
# 192     0       0

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from imblearn.metrics import macro_averaged_mean_absolute_error

print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
print(confusion_matrix(test_df.target, test_df.pred))
# Out:
# Accuracy ->  0.8363636363636363
# Recall ->  0.8532608695652174
# Precision ->  0.8466666666666667
# F1 score ->  0.8361469712015889
# Macro MAE ->  0.1467391304347826
# [[22  1]
#  [ 8 24]]

# %% [markdown]
# ## CNN+LSTM

# %%
model = Sequential()
model.add(Embedding(1848,300,input_length=max_seq_len))

# model.add((Conv1D(16,(3) , activation='tanh' ,return_sequences=True ,  input_shape = (140 , 300) ,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))


model.add(Conv1D(8,(3),activation = 'tanh',kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) ))

model.add(MaxPool1D(3))

# model.add(Bidirectional(LSTM(8,return_sequences=True,activation='tanh',kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)  )))
model.add(Dropout(0.2))
# model.add(BatchNormalization())
model.add(Bidirectional(LSTM(8,activation='tanh',kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) )))


model.add(Dense(128 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model.add(Dropout(0.4))
model.add(Dense(32 , activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model.add(Dense(1, activation='sigmoid' ))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 64, 300)           554400
#
#  conv1d_7 (Conv1D)           (None, 62, 8)             7208
#
#  max_pooling1d_6 (MaxPooling  (None, 20, 8)            0
#  1D)
#
#  dropout_12 (Dropout)        (None, 20, 8)             0
#
#  bidirectional_10 (Bidirecti  (None, 16)               1088
#  onal)
#
#  dense_15 (Dense)            (None, 128)               2176
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 32)                4128
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 569,033
# Trainable params: 569,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

from keras.optimizers import SGD,Adam



# opt = Adam(clipvalue=0.5,learning_rate=0.0001)
opt = Adam(learning_rate=0.0001)
model.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# es_callback = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(word_seq_train, y_train , batch_size=256,
          epochs=25, validation_split=0.10, shuffle=False)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 8s 2s/step - loss: 0.7147 - accuracy: 0.5566 - val_loss: 0.7139 - val_accuracy: 0.6000
# Epoch 2/25
# 2/2 [==============================] - 1s 219ms/step - loss: 0.7144 - accuracy: 0.5385 - val_loss: 0.7129 - val_accuracy: 0.6000
# Epoch 3/25
# 2/2 [==============================] - 0s 187ms/step - loss: 0.7131 - accuracy: 0.5498 - val_loss: 0.7119 - val_accuracy: 0.6000
# Epoch 4/25
# 2/2 [==============================] - 0s 169ms/step - loss: 0.7132 - accuracy: 0.5452 - val_loss: 0.7109 - val_accuracy: 0.6000
# Epoch 5/25
# 2/2 [==============================] - 0s 175ms/step - loss: 0.7132 - accuracy: 0.5452 - val_loss: 0.7100 - val_accuracy: 0.6000
# Epoch 6/25
# 2/2 [==============================] - 0s 180ms/step - loss: 0.7127 - accuracy: 0.5475 - val_loss: 0.7090 - val_accuracy: 0.6000
# Epoch 7/25
# 2/2 [==============================] - 0s 187ms/step - loss: 0.7119 - accuracy: 0.5475 - val_loss: 0.7081 - val_accuracy: 0.6000
# Epoch 8/25
# 2/2 [==============================] - 0s 197ms/step - loss: 0.7117 - accuracy: 0.5475 - val_loss: 0.7071 - val_accuracy: 0.6000
# Epoch 9/25
# 2/2 [==============================] - 0s 192ms/step - loss: 0.7107 - accuracy: 0.5475 - val_loss: 0.7062 - val_accuracy: 0.6000
# Epoch 10/25
# 2/2 [==============================] - 0s 200ms/step - loss: 0.7110 - accuracy: 0.5475 - val_loss: 0.7052 - val_accuracy: 0.6000
# Epoch 11/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.7097 - accuracy: 0.5475 - val_loss: 0.7042 - val_accuracy: 0.6000
# Epoch 12/25
# 2/2 [==============================] - 0s 173ms/step - loss: 0.7095 - accuracy: 0.5475 - val_loss: 0.7031 - val_accuracy: 0.6000
# Epoch 13/25
# 2/2 [==============================] - 0s 179ms/step - loss: 0.7095 - accuracy: 0.5475 - val_loss: 0.7021 - val_accuracy: 0.6000
# Epoch 14/25
# 2/2 [==============================] - 0s 200ms/step - loss: 0.7072 - accuracy: 0.5475 - val_loss: 0.7011 - val_accuracy: 0.6000
# Epoch 15/25
# 2/2 [==============================] - 0s 174ms/step - loss: 0.7088 - accuracy: 0.5475 - val_loss: 0.7001 - val_accuracy: 0.6000
# Epoch 16/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.7065 - accuracy: 0.5475 - val_loss: 0.6991 - val_accuracy: 0.6000
# Epoch 17/25
# 2/2 [==============================] - 0s 187ms/step - loss: 0.7067 - accuracy: 0.5475 - val_loss: 0.6981 - val_accuracy: 0.6000
# Epoch 18/25
# 2/2 [==============================] - 0s 174ms/step - loss: 0.7060 - accuracy: 0.5475 - val_loss: 0.6971 - val_accuracy: 0.6000
# Epoch 19/25
# 2/2 [==============================] - 0s 182ms/step - loss: 0.7045 - accuracy: 0.5475 - val_loss: 0.6961 - val_accuracy: 0.6000
# Epoch 20/25
# 2/2 [==============================] - 0s 193ms/step - loss: 0.7048 - accuracy: 0.5475 - val_loss: 0.6950 - val_accuracy: 0.6000
# Epoch 21/25
# 2/2 [==============================] - 0s 192ms/step - loss: 0.7049 - accuracy: 0.5475 - val_loss: 0.6940 - val_accuracy: 0.6000
# Epoch 22/25
# 2/2 [==============================] - 0s 198ms/step - loss: 0.7037 - accuracy: 0.5475 - val_loss: 0.6930 - val_accuracy: 0.6000
# Epoch 23/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.7031 - accuracy: 0.5475 - val_loss: 0.6920 - val_accuracy: 0.6000
# Epoch 24/25
# 2/2 [==============================] - 0s 206ms/step - loss: 0.7025 - accuracy: 0.5543 - val_loss: 0.6910 - val_accuracy: 0.6000
# Epoch 25/25
# 2/2 [==============================] - 0s 171ms/step - loss: 0.7020 - accuracy: 0.5498 - val_loss: 0.6900 - val_accuracy: 0.6000

# %%
#generate plots
plt.figure()
plt.plot(history.history['loss'], lw=2.0, color='b', label='train')
plt.plot(history.history['val_loss'], lw=2.0, color='r', label='val')
plt.title('LSTM sentiment')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure()
plt.plot(history.history['accuracy'], lw=2.0, color='b', label='train')
plt.plot(history.history['val_accuracy'], lw=2.0, color='r', label='val')
plt.title('LSTM sentiment')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
predictions = model.predict(word_seq_test)
# predictions= predictions.ravel()

# sample=pd.read_csv('test_dat.csv')
test_df['pred']= (predictions>0.5).astype(int)
test_df[['pred', "target"]]
# Out:
# 2/2 [==============================] - 1s 13ms/step
#      pred  target
# 176     1       0
# 77      1       0
# 361     1       1
# 90      1       0
# 368     1       1
# 210     1       0
# 177     1       0
# 250     1       1
# 518     1       1
# 199     1       0
# 6       1       0
# 354     1       1
# 424     1       1
# 261     1       1
# 247     1       1
# 316     1       1
# 501     1       1
# 55      1       0
# 470     1       1
# 499     1       1
# 72      1       0
# 440     1       1
# 540     1       1
# 225     1       0
# 312     1       1
# 2       1       0
# 388     1       1
# 185     1       0
# 10      1       0
# 163     1       0
# 70      1       0
# 286     1       1
# 79      1       0
# 395     1       1
# 396     1       1
# 469     1       1
# 211     1       0
# 433     1       1
# 514     1       1
# 277     1       1
# 158     1       0
# 431     1       1
# 76      1       0
# 297     1       1
# 367     1       1
# 403     1       1
# 83      1       0
# 137     1       0
# 426     1       1
# 542     1       1
# 30      1       0
# 477     1       1
# 398     1       1
# 325     1       1
# 192     1       0

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from imblearn.metrics import macro_averaged_mean_absolute_error

print("Accuracy -> ",accuracy_score(test_df.target, test_df.pred))
print("Recall -> ",recall_score(test_df.target, test_df.pred,average='macro'))
print("Precision -> ",precision_score(test_df.target, test_df.pred,average='macro'))
print("F1 score -> ",f1_score(test_df.target, test_df.pred,average='macro'))
# print("MAE -> ",mean_absolute_error(test_df.target, test_df.pred))
print("Macro MAE -> ",macro_averaged_mean_absolute_error(test_df.target, test_df.pred))
print(confusion_matrix(test_df.target, test_df.pred))
# Out:
# Accuracy ->  0.5818181818181818
# Recall ->  0.5
# Precision ->  0.2909090909090909
# F1 score ->  0.367816091954023
# Macro MAE ->  0.5
# [[ 0 23]
#  [ 0 32]]
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
