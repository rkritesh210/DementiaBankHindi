# %%
# !pip install seqeval
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: seqeval in /usr/local/lib/python3.9/dist-packages (1.2.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.9/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from seqeval) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.10.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
import nltk
import re
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.stem import WordNetLemmatizer
import itertools
from wordcloud import WordCloud
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from keras.models import Sequential,Model
from keras.layers import Dense,LSTM, SpatialDropout1D, Embedding
from keras.utils.np_utils import to_categorical
from joblib import dump, load

# %%
text = []
clas = []
df = pd.read_csv('/content/drive/MyDrive/Hindi AD/new_Manual_dataset.csv',dtype = "str")
df
# Out:
#                                                   text  \
# 0    the scene is in the kitchen.the mother is wipi...
# 1    oh i see the sink is running over . i see the ...
# 2    a boy and a girl are in the kitchen with their...
# 3    okay . it was summertime and mother and the ch...
# 4    wait until i put my glasses on . oh there's a ...
# ..                                                 ...
# 543  well the little kid's falling off his stool . ...
# 544  mhm . well this one is in the cookie jar . and...
# 545  hm  the little boy is on the stool which is ti...
# 546  oh you want me to tell you . the mother and he...
# 547  oh that kid's gonna get a good spill off of th...
#
#                                 google_translated_text  \
# 0    दृश्य रसोई में है। माँ व्यंजन पोंछ रही है और प...
# 1    ओह, मुझे लगता है कि सिंक खत्म हो रहा है। मुझे ...
# 2    एक लड़का और एक लड़की अपनी माँ के साथ रसोई में ...
# 3    ठीक है । यह गर्मियों में था और माँ और बच्चे रस...
# 4    तब तक रुको जब तक मैं अपना चश्मा नहीं डालता। ओह...
# ..                                                 ...
# 543  खैर छोटा बच्चा अपने स्टूल से गिर रहा है। और मा...
# 544  एमएचएम। खैर यह एक कुकी जार में है। और उसने चढ़...
# 545  एचएम छोटा लड़का स्टूल पर है जो टिपिंग कर रहा ह...
# 546  ओह, आप चाहते हैं कि मैं आपको बताऊं। माँ और उसक...
# 547  ओह, कि बच्चे को उस स्टूल से एक अच्छा फैल जाना ...
#
#                                            mbart50_m2m  \
# 0    दृश्य रसोई में है। मां बर्तन धो रही है और पानी...
# 1    ओह मैं देखता हूँ सिंक ऊपर चल रहा है। मैं देखता...
# 2    एक लड़का और एक लड़की मां के साथ रसोईघर में हैं...
# 3    ठीक है। यह गर्मी का समय था और माँ और बच्चे रसो...
# 4    जब तक मैं अपने चश्मा लगाएं तक प्रतीक्षा करें। ...
# ..                                                 ...
# 543  ठीक है, छोटा बच्चा अपनी कुर्सी से गिर रहा है। ...
# 544  mhm। यह एक कुकी के बर्तन में है। और वो चढ़ने क...
# 545  हां, छोटा लड़का स्टूल पर है जो झुक रहा है और व...
# 546  ओह तुम चाहते हो कि मैं तुम्हें बता दूँ। मां और...
# 547  ओह उस बच्चे को उस स्टूल से अच्छी तरह से बाहर न...
#
#                                           m2m_100_1.2B  \
# 0    दृश्य रसोईघर में है. माँ डिश धो रही है और पानी...
# 1    मैं देखता हूं कि सिंहासन चल रहा है। मैं देखता ...
# 2    एक लड़का और एक लड़की अपनी मां के साथ रसोई में ...
# 3    ठीक है। यह गर्मियों का समय था और माँ और बच्चे ...
# 4    तब तक इंतज़ार करें जब तक मैं अपने चश्मा पहनता ...
# ..                                                 ...
# 543  छोटा बच्चा अपने कुर्सी से गिर रहा है। माँ के प...
# 544  एमएम यह एक कुकी जार में है। और वह चढ़ने की कोश...
# 545  हाँ, छोटा लड़का कुर्सी पर है जो टिपिंग कर रहा ...
# 546  आप चाहते हैं कि मैं आपको बताऊं। मां और उसके दो...
# 547  ओह, उस बच्चे को उस मल से अच्छी तरह से फेंक दिय...
#
#                                                opus-mt    Result Labels  \
# 0    यह दृश्‍य किचिन में है । एक लड़का एक घड़े से क...   Control      0
# 1    ओह मैं सिंक खत्म हो रहा है देखते हैं. मुझे लगत...   Control      0
# 2    एक लड़का और लड़की रसोई में अपनी माँ के साथ हैं...   Control      0
# 3    ठीक है. गर्मियों का मौसम था और माँ और बच्चे रस...   Control      0
# 4    मैं पर मेरे चश्मा डाल जब तक इंतजार करें. ओह, ए...   Control      0
# ..                                                 ...       ...    ...
# 543  छोटा बच्चा अपनी चौकी से गिर रहा है. और वह (बस्...  Dementia      1
# 544  mh. अच्छी तरह से इस आदमी कुकी जार में है. और व...  Dementia      1
# 545  छोटे लड़के को उस चौकी पर है जिस पर सरकना है और...  Dementia      1
# 546  ओह तुम मुझे तुम्हें बताने के लिए चाहते हैं. मा...  Dementia      1
# 547  ओह है कि बच्चे वहाँ के चारों ओर नहीं बारी है क...  Dementia      1
#
#                                           manual_trans
# 0    दृश्य रसोई की है। माँ बर्तन पोंछ रही है और पान...
# 1    ओह, मैं देख रहा हूँ कि सिंक बह निकला है।मैं दे...
# 2    एक लड़का और एक लड़की रसोई में अपनी माँ के साथ ...
# 3    गर्मी का मौसम था और माँ और बच्चे रसोई में काम ...
# 4    जब तक मैं अपना चश्मा नहीं लगाता तब तक प्रतीक्ष...
# ..                                                 ...
# 543  अच्छ छोटा बच्चा अपने मल से गिर रहा है। और माँ ...
# 544  महम। अच्छा यह कुकी जार में है। और उसने चढ़ने क...
# 545  हम्म छोटा लड़का स्टूल पर है जो ढो रहा है और वह...
# 546  ओह, आप चाहते हैं कि मैं आपको बता दूं। माँ और उ...
# 547  अगर उसकी माँ वहाँ नहीं घूमी और उसे पकड़ नहीं ल...
#
# [548 rows x 8 columns]

# %%
text = df['m2m_100_1.2B'].tolist()
clas = df['Labels'].tolist()

df = pd.DataFrame({'tweet': text, 'class': clas})

# %%
df
# Out:
#                                                  tweet class
# 0    दृश्य रसोईघर में है. माँ डिश धो रही है और पानी...     0
# 1    मैं देखता हूं कि सिंहासन चल रहा है। मैं देखता ...     0
# 2    एक लड़का और एक लड़की अपनी मां के साथ रसोई में ...     0
# 3    ठीक है। यह गर्मियों का समय था और माँ और बच्चे ...     0
# 4    तब तक इंतज़ार करें जब तक मैं अपने चश्मा पहनता ...     0
# ..                                                 ...   ...
# 543  छोटा बच्चा अपने कुर्सी से गिर रहा है। माँ के प...     1
# 544  एमएम यह एक कुकी जार में है। और वह चढ़ने की कोश...     1
# 545  हाँ, छोटा लड़का कुर्सी पर है जो टिपिंग कर रहा ...     1
# 546  आप चाहते हैं कि मैं आपको बताऊं। मां और उसके दो...     1
# 547  ओह, उस बच्चे को उस मल से अच्छी तरह से फेंक दिय...     1
#
# [548 rows x 2 columns]

# %% [markdown]
# # text cleaning

# %%
df['tweet'] = df[['tweet']].apply(lambda x: x.str.strip()).replace('', np.nan)
df = df.dropna(subset=['tweet'])
df.reset_index(drop=True, inplace=True)

# %%
df['tweet'] = df['tweet'].apply(lambda x:x.lower())

# %%
punctuation_signs = list("?:!.,;|।")
df['tweet'] = df['tweet']

for punct_sign in punctuation_signs:   
    df['tweet'] = df['tweet'].str.replace(punct_sign, '')
# Out:
# <ipython-input-42-58185447e27a>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['tweet'] = df['tweet'].str.replace(punct_sign, '')

# %%
df['tweet'] = df['tweet'].apply(lambda x: x.replace('\n', ' '))
df['tweet'] = df['tweet'].apply(lambda x: x.replace('\t', ' '))
df['tweet'] = df['tweet'].apply(lambda x: x.replace('।', ' '))
df['tweet'] = df['tweet'].str.replace("    ", " ")
df['tweet'] = df['tweet'].str.replace('"', '')
df['tweet'] = df['tweet'].str.replace("'s", "")

# %%
nltk.download('stopwords')
stop_words = list(stopwords.words('english'))
for stop_word in stop_words:
    regex_stopword = r"\b" + stop_word + r"\b"
    df['tweet'] = df['tweet'].str.replace(regex_stopword, '')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-44-969333b8111c>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['tweet'] = df['tweet'].str.replace(regex_stopword, '')

# %%
import re
Tweet = []
for tweettext in df["tweet"]:
  text = re.sub(r"http\S+", "", tweettext)
  text = re.sub(r"@\S+"," ",text)
  emoji_pattern = re.compile("["
                            u"\U0001F600-\U0001F64F"  # emoticons
                            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                            u"\U0001F680-\U0001F6FF"  # transport & map symbols
                            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                            u"\U00002500-\U00002BEF"  # chinese char
                            u"\U00002702-\U000027B0"
                            u"\U00002702-\U000027B0"
                            u"\U000024C2-\U0001F251"
                            u"\U0001f926-\U0001f937"
                            u"\U00010000-\U0010ffff"
                            u"\u2640-\u2642"
                            u"\u2600-\u2B55"
                            u"\u200d"
                            u"\u23cf"
                            u"\u23e9"
                            u"\u231a"
                            u"\ufe0f"  # dingbats
                            u"\u3030"
                            "]+", flags=re.UNICODE)

  text = emoji_pattern.sub('',text)
  text = text.replace("#","")
  text = text.replace("|","")
  text = text.replace('\n',"")
  text = text.replace('!',"")
  text = re.sub("\xa0|©|\xad|⏬|\u200b|\u200c|–|—|‘|’|“|”|•|…|\u202f|‼|⁉|\u2066|ఎ|క|గ|చ|జ|ట|డ|త|న|ప|బ|మ|య|ర|ల|ష|స|హ|ਅ|ਆ|ਇ|ਈ|ਊ|ਓ|ਕ|ਗ|ਚ|ਜ|ਝ|ਟ|ਠ|ਡ|ਤ|ਦ|ਨ|ਪ|ਬ|ਮ|ਰ|ਲ|ਵ|ਸ|ਹ|લ|સ|હ","",text)
  text = re.sub("$|%|&|(|)|-|/|=|@|[|]|_|{|}|~|","",text)
  text = text.replace("+","")
#   text = re.sub(r'\b\d\w*\b', '', text)
#   text = re.sub('[^A-Za-z0-9]+', ' ', text)
#   print(text)
  Tweet.append(text)

# %%
corpus = ""
for i in Tweet:
    corpus = corpus + ' ' + i 
letters = set(corpus)

# %%
len(list(letters))
# Out:
# 88

# %%
df["tweet"] = Tweet
df
# Out:
#                                                  tweet class
# 0    दृश्य रसोईघर में है माँ डिश धो रही है और पानी ...     0
# 1    मैं देखता हूं कि सिंहासन चल रहा है मैं देखता ह...     0
# 2    एक लड़का और एक लड़की अपनी मां के साथ रसोई में ...     0
# 3    ठीक है यह गर्मियों का समय था और माँ और बच्चे र...     0
# 4    तब तक इंतज़ार करें जब तक मैं अपने चश्मा पहनता ...     0
# ..                                                 ...   ...
# 543  छोटा बच्चा अपने कुर्सी से गिर रहा है माँ के पा...     1
# 544  एमएम यह एक कुकी जार में है और वह चढ़ने की कोशि...     1
# 545  हाँ छोटा लड़का कुर्सी पर है जो टिपिंग कर रहा ह...     1
# 546  आप चाहते हैं कि मैं आपको बताऊं मां और उसके दो ...     1
# 547  ओह उस बच्चे को उस मल से अच्छी तरह से फेंक दिया...     1
#
# [548 rows x 2 columns]

# %% [markdown]
# # ML models

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['tweet']).toarray()
y = df['class'].map(int)

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# scaler.fit(X)
# X = scaler.transform(X)

# %%
# cv = CountVectorizer()
# X = cv.fit_transform(df['tweet']).toarray()
# y = df['class'].map(int)

# %%
metrics_df = pd.DataFrame(index = ["mae macro average","precision macro average", "recall macro average ", "f1 score marco average", "classification_report"])

# %%
metrics_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [mae macro average, precision macro average, recall macro average , f1 score marco average, classification_report]

# %% [markdown]
# imbalance upscale

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,  random_state = 42)

# %%
# from imblearn.over_sampling import SMOTE, ADASYN
# X_train, y_train = SMOTE().fit_resample(X_train, y_train)

# %%
from imblearn.metrics import macro_averaged_mean_absolute_error
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
def metrics_print(y_pred, y_test,model,df):


    
    mae = macro_averaged_mean_absolute_error(y_pred, y_test)
    y_pred = y_pred.astype('str')
    y_test =y_test.map(str)
    y_test = y_test.values
    precision = precision_score(y_pred, y_test,average = 'macro')
    recall = recall_score(y_pred, y_test,average = 'macro')
    class_rep = classification_report(y_pred, y_test)
    f1 = f1_score(y_pred, y_test,average = 'macro')
    
    print("Mean Absoulte error", mae)
    print("precision score",precision)
    print("recall score",recall)
    print("classification report")
    print("F1 Score",f1)
    print(class_rep)
    df[model] = [mae,precision, recall,f1,class_rep]
    return df

def plot_confusion_matrix(cm,y_test,y_pred,model,df,classes,
                                            normalize=False,
                                            title='Confusion matrix',
                                                cmap=plt.cm.Blues):
    
    df = metrics_print(y_pred,y_test,model,df)
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return df

# %%
clf = RandomForestClassifier(n_estimators=100)
clf = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("accuracy is: ",accuracy)
CM = confusion_matrix(y_test, y_pred)

metrics_df = plot_confusion_matrix(CM ,y_test, y_pred,"Random Forest",metrics_df,classes = range(3))
dump(clf, 'rf.joblib')
# Out:
# accuracy is:  0.7272727272727273
# Mean Absoulte error 0.26785714285714285
# precision score 0.7166666666666667
# recall score 0.7321428571428572
# classification report
# F1 Score 0.7179487179487178
#               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67        60
#            1       0.83      0.71      0.77       105
#
#     accuracy                           0.73       165
#    macro avg       0.72      0.73      0.72       165
# weighted avg       0.75      0.73      0.73       165
# ['rf.joblib']

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("accuracy is: ",accuracy)
CM = confusion_matrix(y_test, y_pred)
metrics_df = plot_confusion_matrix(CM ,y_test, y_pred,"Decision Tree",metrics_df,classes = range(3))
dump(clf, 'decision.joblib')
# Out:
# accuracy is:  0.6242424242424243
# Mean Absoulte error 0.37816764132553604
# precision score 0.6111111111111112
# recall score 0.621832358674464
# classification report
# F1 Score 0.6085858585858586
#               precision    recall  f1-score   support
#
#            0       0.47      0.61      0.53        57
#            1       0.76      0.63      0.69       108
#
#     accuracy                           0.62       165
#    macro avg       0.61      0.62      0.61       165
# weighted avg       0.66      0.62      0.63       165
# ['decision.joblib']

# %%
from sklearn.naive_bayes import MultinomialNB
gau = MultinomialNB()
gau = gau.fit(X_train, y_train)
y_pred = gau.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("accuracy is: ",accuracy)
CM = confusion_matrix(y_test, y_pred)
metrics_df = plot_confusion_matrix(CM ,y_test, y_pred,"Multi-Nomial Naive Bayes",metrics_df,classes = range(3))
dump(gau, 'GaussianNaiveBayes.joblib')
# Out:
# accuracy is:  0.6848484848484848
# Mean Absoulte error 0.2771672771672772
# precision score 0.6622222222222223
# recall score 0.7228327228327228
# classification report
# F1 Score 0.651559454191033
#               precision    recall  f1-score   support
#
#            0       0.41      0.79      0.54        39
#            1       0.91      0.65      0.76       126
#
#     accuracy                           0.68       165
#    macro avg       0.66      0.72      0.65       165
# weighted avg       0.79      0.68      0.71       165
# ['GaussianNaiveBayes.joblib']

# %%
from sklearn.svm import SVC
svm = SVC(max_iter = 1000)
svm = svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("accuracy is: ",accuracy)
CM = confusion_matrix(y_test, y_pred)
metrics_df = plot_confusion_matrix(CM ,y_test, y_pred,"SVC",metrics_df,classes = range(3))
dump(svm, 'SVM.joblib')
# Out:
# accuracy is:  0.6909090909090909
# Mean Absoulte error 0.3097153465346535
# precision score 0.6822222222222223
# recall score 0.6902846534653465
# classification report
# F1 Score 0.6830389091867866
#               precision    recall  f1-score   support
#
#            0       0.59      0.69      0.63        64
#            1       0.78      0.69      0.73       101
#
#     accuracy                           0.69       165
#    macro avg       0.68      0.69      0.68       165
# weighted avg       0.70      0.69      0.69       165
# ['SVM.joblib']

# %%
from sklearn.linear_model import LogisticRegression
logi = LogisticRegression(max_iter = 1000)
logi = logi.fit(X_train, y_train)
y_pred = logi.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("accuracy is: ",accuracy)
CM = confusion_matrix(y_test, y_pred)
metrics_df = plot_confusion_matrix(CM ,y_test, y_pred,"Logistic Regression",metrics_df,classes = range(3))
dump(logi, 'LogisticRegression.joblib')
# Out:
# accuracy is:  0.6909090909090909
# Mean Absoulte error 0.30714285714285716
# precision score 0.68
# recall score 0.6928571428571428
# classification report
# F1 Score 0.6803418803418804
#               precision    recall  f1-score   support
#
#            0       0.56      0.70      0.62        60
#            1       0.80      0.69      0.74       105
#
#     accuracy                           0.69       165
#    macro avg       0.68      0.69      0.68       165
# weighted avg       0.71      0.69      0.70       165
# ['LogisticRegression.joblib']

# %%
from xgboost import XGBClassifier
logi = XGBClassifier(random_state=42, seed=2, colsample_bytree=0.6, subsample=0.7, n_estimators=300)
logi = logi.fit(X_train, y_train)
y_pred = logi.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("accuracy is: ",accuracy)
CM = confusion_matrix(y_test, y_pred)
metrics_df = plot_confusion_matrix(CM ,y_test, y_pred,"XGB",metrics_df,classes = range(3))
dump(logi, 'XGB.joblib')
# Out:
# accuracy is:  0.6909090909090909
# Mean Absoulte error 0.30714285714285716
# precision score 0.68
# recall score 0.6928571428571428
# classification report
# F1 Score 0.6803418803418804
#               precision    recall  f1-score   support
#
#            0       0.56      0.70      0.62        60
#            1       0.80      0.69      0.74       105
#
#     accuracy                           0.69       165
#    macro avg       0.68      0.69      0.68       165
# weighted avg       0.71      0.69      0.70       165
# ['XGB.joblib']

# %%
from sklearn.ensemble import  AdaBoostClassifier

logi = AdaBoostClassifier(random_state=42, n_estimators=300)
logi = logi.fit(X_train, y_train)
y_pred = logi.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("accuracy is: ",accuracy)
CM = confusion_matrix(y_test, y_pred)
metrics_df = plot_confusion_matrix(CM ,y_test, y_pred,"ADA",metrics_df,classes = range(3))
dump(logi, 'ADA.joblib')
# Out:
# accuracy is:  0.6848484848484848
# Mean Absoulte error 0.3173701298701299
# precision score 0.6833333333333333
# recall score 0.6826298701298701
# classification report
# F1 Score 0.6828799526907156
#               precision    recall  f1-score   support
#
#            0       0.67      0.65      0.66        77
#            1       0.70      0.72      0.71        88
#
#     accuracy                           0.68       165
#    macro avg       0.68      0.68      0.68       165
# weighted avg       0.68      0.68      0.68       165
# ['ADA.joblib']

# %%
metrics_df #m2m_100_1.2B
# Out:
#                                                              Random Forest  \
# mae macro average                                                 0.267857
# precision macro average                                           0.716667
# recall macro average                                              0.732143
# f1 score marco average                                            0.717949
# classification_report                  precision    recall  f1-score   ...
#
#                                                              Decision Tree  \
# mae macro average                                                 0.378168
# precision macro average                                           0.611111
# recall macro average                                              0.621832
# f1 score marco average                                            0.608586
# classification_report                  precision    recall  f1-score   ...
#
#                                                   Multi-Nomial Naive Bayes  \
# mae macro average                                                 0.277167
# precision macro average                                           0.662222
# recall macro average                                              0.722833
# f1 score marco average                                            0.651559
# classification_report                  precision    recall  f1-score   ...
#
#                                                                        SVC  \
# mae macro average                                                 0.309715
# precision macro average                                           0.682222
# recall macro average                                              0.690285
# f1 score marco average                                            0.683039
# classification_report                  precision    recall  f1-score   ...
#
#                                                        Logistic Regression  \
# mae macro average                                                 0.307143
# precision macro average                                               0.68
# recall macro average                                              0.692857
# f1 score marco average                                            0.680342
# classification_report                  precision    recall  f1-score   ...
#
#                                                                        XGB  \
# mae macro average                                                 0.307143
# precision macro average                                               0.68
# recall macro average                                              0.692857
# f1 score marco average                                            0.680342
# classification_report                  precision    recall  f1-score   ...
#
#                                                                        ADA
# mae macro average                                                  0.31737
# precision macro average                                           0.683333
# recall macro average                                               0.68263
# f1 score marco average                                             0.68288
# classification_report                  precision    recall  f1-score   ...

# %%
metrics_df #old-smote
# Out:
#                                                              Random Forest  \
# mae macro average                                                 0.249073
# precision macro average                                           0.751471
# recall macro average                                              0.750927
# f1 score marco average                                            0.751082
# classification_report                  precision    recall  f1-score   ...
#
#                                                              Decision Tree  \
# mae macro average                                                 0.372106
# precision macro average                                           0.628251
# recall macro average                                              0.627894
# f1 score marco average                                              0.6272
# classification_report                  precision    recall  f1-score   ...
#
#                                                   Multi-Nomial Naive Bayes  \
# mae macro average                                                 0.296537
# precision macro average                                           0.703715
# recall macro average                                              0.703463
# f1 score marco average                                            0.701852
# classification_report                  precision    recall  f1-score   ...
#
#                                                                        SVC  \
# mae macro average                                                 0.267857
# precision macro average                                            0.73243
# recall macro average                                              0.732143
# f1 score marco average                                            0.732258
# classification_report                  precision    recall  f1-score   ...
#
#                                                        Logistic Regression
# mae macro average                                                 0.267136
# precision macro average                                           0.730341
# recall macro average                                              0.732864
# f1 score marco average                                            0.730884
# classification_report                  precision    recall  f1-score   ...
